# %% [markdown]
# # Importing Modules

# %%
import warnings, re,math, datetime, time
start_time = time.time()
from datetime import timedelta
warnings.filterwarnings("ignore")
import pandas as pd
import csv, io
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import nltk, string
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from nltk.stem.snowball import SnowballStemmer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
import geopandas as gpd
from geopy import geocoders
gn = geocoders.GeoNames(username = "idselection")
import shapely
from shapely.geometry import Point, LineString, Polygon

# %%
"""
from google.colab import files
uploaded = files.upload()
"""
# Out:
# '\nfrom google.colab import files\nuploaded = files.upload()\n'

# %% [markdown]
# # Loading Election Dataset

# %%
#df = pd.read_csv(io.BytesIO(uploaded['Elections2019.csv']))
df = pd.read_csv("Elections2019.csv")
df.head()
# Out:
#        last_updated      tweet_id        created_at   user_location  \
# 0  06-03-2019 17:30  1.100000e+18  06-03-2019 03:33       Guwahati
# 1  17-03-2019 18:11  1.110000e+18  17-03-2019 17:27             NaN
# 2  23-03-2019 18:07  1.110000e+18  23-03-2019 11:28      New Delhi
# 3  11-03-2019 17:47  1.100000e+18  26-02-2019 07:40             NaN
# 4  27-02-2019 18:18  1.100000e+18  27-02-2019 12:21  Delhi | Odisha
#
#                                            full_text  quote_count  \
# 0  Guwahati has gained a lot of prominence in rec...          0.0
# 1  RSS in school days itself? Indoctrinated since...          0.0
# 2  Words don't exist in Vaccum!\nModi's post Pulw...          0.0
# 3  India's #Icecream Industry stands at 15,000 cr...          0.0
# 4  *40 CRPF Jawans killed in Pulwama Attack\n*IAF...          0.0
#
#    reply_count  retweet_count  favorite_count  hashtags  \
# 0          4.0          113.0             113   ActEast
# 1          0.0            5.0               5       NaN
# 2          4.0           31.0              31       NaN
# 3          0.0            3.0               3  Icecream
# 4          0.0            9.0               9       NaN
#
#   user_mentions_screen_name                         City  State  District  \
# 0              narendramodi                     Guwahati  Assam       NaN
# 1                       NaN                          NaN    NaN       NaN
# 2                       NaN  New Delhi Municipal Council  Delhi       NaN
# 3                       NaN                          NaN    NaN       NaN
# 4                       NaN                          NaN  Delhi       NaN
#
#   Country
# 0   India
# 1   India
# 2   India
# 3   India
# 4   India

# %% [markdown]
# # Dimensions

# %%
df.shape
# Out:
# (46043, 15)

# %% [markdown]
# # Displaying columns with NaN

# %%
df.isnull().sum()
# Out:
# last_updated                     7
# tweet_id                         2
# created_at                       7
# user_location                 5779
# full_text                        2
# quote_count                   1410
# reply_count                   1410
# retweet_count                   12
# favorite_count                   0
# hashtags                     36836
# user_mentions_screen_name    28320
# City                         30330
# State                        28788
# District                     46038
# Country                      20700
# dtype: int64

# %% [markdown]
# # Attribute Data Types

# %%
df.dtypes
# Out:
# last_updated                  object
# tweet_id                     float64
# created_at                    object
# user_location                 object
# full_text                     object
# quote_count                  float64
# reply_count                  float64
# retweet_count                float64
# favorite_count                 int64
# hashtags                      object
# user_mentions_screen_name     object
# City                          object
# State                         object
# District                     float64
# Country                       object
# dtype: object

# %% [markdown]
# # Dropping unnecessary rows and columns

# %%
df = df[pd.notnull(df['created_at'])]
df.dropna(subset=["full_text"], inplace = True)
df.drop("District", axis = 1, inplace =True)
#df.drop("favorite_count", axis = 1, inplace =True)
df.drop("user_location", axis=1, inplace = True)
df.shape
# Out:
# (46036, 13)

# %% [markdown]
# # Removing US tweets

# %%
usa_terms = ["usa", "united states", "trump", "america", "democrat","cia", "fbi", "nsa"]
for i in range(0,46043):
    try:
        flag = True
        x = df.loc[i,"full_text"]
        #print(x)
        for j in usa_terms:
            if j in str(x).lower():
                flag = False
                break
        if flag==False:
            df = df.drop(i)
    except:
        pass
df = df[df["Country"] != "Others"]

# %%
df.shape
# Out:
# (39874, 13)

# %% [markdown]
# # Replacing NaN values

# %%
df["Country"].fillna("India", inplace=True)
df["retweet_count"].fillna(0, inplace=True)
df["quote_count"].fillna(0, inplace=True)
df["reply_count"].fillna(0, inplace=True)
df["favorite_count"].fillna(0, inplace=True)
df["State"].fillna("", inplace=True)
df["hashtags"].fillna("", inplace=True)
df["user_mentions_screen_name"].fillna("", inplace=True)
df["Country"]=df["Country"].replace("0","India") 
df["Country"]=df["Country"].replace("1","India")
df["Country"]=df["Country"].replace("2","India")
df["State"]=df["State"].replace("0","")
df["State"]=df["State"].replace("1","")
df["State"]=df["State"].replace("2","")
df["City"].fillna("", inplace=True)

# %%
df.head()
# Out:
#        last_updated      tweet_id        created_at  \
# 0  06-03-2019 17:30  1.100000e+18  06-03-2019 03:33
# 1  17-03-2019 18:11  1.110000e+18  17-03-2019 17:27
# 2  23-03-2019 18:07  1.110000e+18  23-03-2019 11:28
# 3  11-03-2019 17:47  1.100000e+18  26-02-2019 07:40
# 4  27-02-2019 18:18  1.100000e+18  27-02-2019 12:21
#
#                                            full_text  quote_count  \
# 0  Guwahati has gained a lot of prominence in rec...          0.0
# 1  RSS in school days itself? Indoctrinated since...          0.0
# 2  Words don't exist in Vaccum!\nModi's post Pulw...          0.0
# 3  India's #Icecream Industry stands at 15,000 cr...          0.0
# 4  *40 CRPF Jawans killed in Pulwama Attack\n*IAF...          0.0
#
#    reply_count  retweet_count  favorite_count  hashtags  \
# 0          4.0          113.0             113   ActEast
# 1          0.0            5.0               5
# 2          4.0           31.0              31
# 3          0.0            3.0               3  Icecream
# 4          0.0            9.0               9
#
#   user_mentions_screen_name                         City  State Country
# 0              narendramodi                     Guwahati  Assam   India
# 1                                                                 India
# 2                            New Delhi Municipal Council  Delhi   India
# 3                                                                 India
# 4                                                         Delhi   India

# %% [markdown]
# # Fixing Dates

# %%
lastupdate, created = [], []
for i in df["last_updated"]:
    lastupdate.append(datetime.datetime.strptime(i, "%d-%m-%Y %H:%M"))
for i in df["created_at"]:
    created.append(datetime.datetime.strptime(i, "%d-%m-%Y %H:%M"))

# %%
df["created_at"] = created
df["last_updated"] = lastupdate
df.drop(df[df['last_updated'] > datetime.datetime(2019,5,23,0,0)].index, inplace = True) 
df.drop(df[df['created_at'] > datetime.datetime(2019,5,23,0,0)].index, inplace = True)

# %%
df.head()
# Out:
#          last_updated      tweet_id          created_at  \
# 0 2019-03-06 17:30:00  1.100000e+18 2019-03-06 03:33:00
# 1 2019-03-17 18:11:00  1.110000e+18 2019-03-17 17:27:00
# 2 2019-03-23 18:07:00  1.110000e+18 2019-03-23 11:28:00
# 3 2019-03-11 17:47:00  1.100000e+18 2019-02-26 07:40:00
# 4 2019-02-27 18:18:00  1.100000e+18 2019-02-27 12:21:00
#
#                                            full_text  quote_count  \
# 0  Guwahati has gained a lot of prominence in rec...          0.0
# 1  RSS in school days itself? Indoctrinated since...          0.0
# 2  Words don't exist in Vaccum!\nModi's post Pulw...          0.0
# 3  India's #Icecream Industry stands at 15,000 cr...          0.0
# 4  *40 CRPF Jawans killed in Pulwama Attack\n*IAF...          0.0
#
#    reply_count  retweet_count  favorite_count  hashtags  \
# 0          4.0          113.0             113   ActEast
# 1          0.0            5.0               5
# 2          4.0           31.0              31
# 3          0.0            3.0               3  Icecream
# 4          0.0            9.0               9
#
#   user_mentions_screen_name                         City  State Country
# 0              narendramodi                     Guwahati  Assam   India
# 1                                                                 India
# 2                            New Delhi Municipal Council  Delhi   India
# 3                                                                 India
# 4                                                         Delhi   India

# %% [markdown]
# # Sorting Dataset by Dates

# %%
df = df.sort_values(by=['last_updated'])

# %%
df.head()
# Out:
#              last_updated      tweet_id          created_at  \
# 13334 2019-02-08 17:29:00  1.090000e+18 2019-02-08 17:28:00
# 9793  2019-02-08 17:29:00  1.090000e+18 2019-02-07 05:10:00
# 32798 2019-02-08 17:30:00  1.090000e+18 2019-02-08 10:18:00
# 34596 2019-02-08 17:30:00  1.090000e+18 2019-02-08 17:29:00
# 28070 2019-02-08 17:30:00  1.090000e+18 2019-02-08 14:19:00
#
#                                                full_text  quote_count  \
# 13334  @DasComrade Sir any comment on modi's grand en...          0.0
# 9793   Congress made Vemula national talking point ev...         47.0
# 32798  BJP has been winning battles over the past mon...          1.0
# 34596  @inclusivemind2 @Ark82876233 @BJP4India @Rahul...          0.0
# 28070  Senior Congress leader @ManishTewari : There w...          0.0
#
#        reply_count  retweet_count  favorite_count hashtags  \
# 13334          0.0            1.0               1
# 9793          72.0         2353.0            2353
# 32798         12.0          513.0             513
# 34596          0.0            2.0               2
# 28070          1.0          159.0             159
#
#                               user_mentions_screen_name  \
# 13334                                        DasComrade
# 9793
# 32798
# 34596  inclusivemind2,Ark82876233,BJP4India,RahulGandhi
# 28070                                      ManishTewari
#
#                               City          State Country
# 13334                     Guwahati          Assam   India
# 9793                Greater Mumbai    Maharashtra   India
# 32798                      Kolkata    West Bengal   India
# 34596                      Aligarh  Uttar Pradesh   India
# 28070  New Delhi Municipal Council          Delhi   India

# %% [markdown]
# # New Dimensions after dropping rows and columns

# %%
df.shape
# Out:
# (39874, 13)

# %% [markdown]
# # Showing NaN

# %%
df.isnull().sum()
# Out:
# last_updated                 0
# tweet_id                     0
# created_at                   0
# full_text                    0
# quote_count                  0
# reply_count                  0
# retweet_count                0
# favorite_count               0
# hashtags                     0
# user_mentions_screen_name    0
# City                         0
# State                        0
# Country                      0
# dtype: int64

# %% [markdown]
# # Mapping Cities and States

# %%
capitals = dict(zip(
    ['Delhi', 'Karnataka', 'Andhra Pradesh', 'Maharashtra',
       'Punjab', 'Uttar Pradesh', 'Gujarat', 'Pondicherry', 'Jharkhand',
       'Chandigarh', 'Madhya Pradesh', 'West Bengal', 'Assam',
       'Jammu & Kashmir', 'Bihar', 'Haryana', 'Tamil Nadu', 'Orissa',
       'Chhattisgarh', 'Rajasthan', 'Uttaranchal', 'Telangana',
       'Daman & Diu', 'Meghalaya', 'Tripura', 'Kerala', 'Goa',
       'Himachal Pradesh', 'Manipur', 'Arunachal Pradesh', 'Lakshadweep',
       'Andaman & Nicobar Islands', 'Mizoram', 'Nagaland', 'Sikkim'],
                    
    ['New Delhi','Bangalore','Hyderabad','Mumbai','Chandigarh','Lucknow', 'Gandhinagar', 'Pondicherry',"Ranchi","Chandigarh",
         "Bhopal", "Kolkata", "Dispur", "Srinagar", "Patna", "Chandigarh", "Chennai", "Bhubaneswar", "Raipur",
        "Jaipur", "Dehradun", "Hyderabad", "Daman", "Shillong", "Agartala", "Trivandrum", "Panaji", "Shimla",
        "Imphal", "Itanagar", "Kavaratti", "Port Blair", "Aizawl", "Kohima","Gangtok"]))

# %% [markdown]
# # Replacing NULL cities to state capitals

# %%
for i in range(0,46044):
    try:
        if df["City"][i]=='':
            df["City"][i] = capitals[df["State"][i]]
    except:
        pass
df.head()
# Out:
#              last_updated      tweet_id          created_at  \
# 13334 2019-02-08 17:29:00  1.090000e+18 2019-02-08 17:28:00
# 9793  2019-02-08 17:29:00  1.090000e+18 2019-02-07 05:10:00
# 32798 2019-02-08 17:30:00  1.090000e+18 2019-02-08 10:18:00
# 34596 2019-02-08 17:30:00  1.090000e+18 2019-02-08 17:29:00
# 28070 2019-02-08 17:30:00  1.090000e+18 2019-02-08 14:19:00
#
#                                                full_text  quote_count  \
# 13334  @DasComrade Sir any comment on modi's grand en...          0.0
# 9793   Congress made Vemula national talking point ev...         47.0
# 32798  BJP has been winning battles over the past mon...          1.0
# 34596  @inclusivemind2 @Ark82876233 @BJP4India @Rahul...          0.0
# 28070  Senior Congress leader @ManishTewari : There w...          0.0
#
#        reply_count  retweet_count  favorite_count hashtags  \
# 13334          0.0            1.0               1
# 9793          72.0         2353.0            2353
# 32798         12.0          513.0             513
# 34596          0.0            2.0               2
# 28070          1.0          159.0             159
#
#                               user_mentions_screen_name  \
# 13334                                        DasComrade
# 9793
# 32798
# 34596  inclusivemind2,Ark82876233,BJP4India,RahulGandhi
# 28070                                      ManishTewari
#
#                               City          State Country
# 13334                     Guwahati          Assam   India
# 9793                Greater Mumbai    Maharashtra   India
# 32798                      Kolkata    West Bengal   India
# 34596                      Aligarh  Uttar Pradesh   India
# 28070  New Delhi Municipal Council          Delhi   India

# %% [markdown]
# # Finding city name variations

# %%
d = {}
for i in df["City"]:
    #print("Checking for ",i)
    if i not in d:
        d[i]=set()
    for j in df["City"]:
        if(i in j and i!=''):
            d[i].add(j)
for i in d:
    if len(d[i])>1:
        print(i,d[i])
# Out:
# Hyderabad {'Hyderabad', 'Hyderabad M.Corp'}
# New Delhi {'New Delhi', 'New Delhi Municipal Council'}
# Mumbai {'Navi Mumbai', 'Mumbai', 'Greater Mumbai'}
# Anand {'Anand Nagar', 'Anand'}
# Rewa {'Rewari', 'Rewa'}
# Nagar {'L.B. Nagar', 'Nagar', 'S.A.S. Nagar (Mohali)', 'Anand Nagar', 'Jemari  (J.K. Nagar Township)'}
# Thane {'Thanesar', 'Kalambe Turf Thane', 'Thane'}
# Ara {'Arani', 'Ara'}
# Jodhpur {'Jodhpur', 'Jam Jodhpur'}
# Bad {'Badgam', 'Bad'}
# Bokaro {'Bokaro', 'Bokaro Steel City'}
# Bagh {'Bagh', 'Baghpat'}
# Durg {'Durgapur', 'Durg'}
# Banga {'Banga', 'Bangalore'}
# Udaipur {'Udaipur', 'Chhota Udaipur'}
# Ambikapur {'Ambikapur', 'Ambikapur Part-X'}
# Lakhimpur {'North Lakhimpur', 'Lakhimpur'}

# %% [markdown]
# # Modifying variations of city names

# %%
df["City"]=df["City"].replace("Navi Mumbai","Mumbai")
df["City"]=df["City"].replace("Greater Mumbai","Mumbai")
df["City"]=df["City"].replace("Bokaro Steel City","Bokaro")
df["City"]=df["City"].replace("L.B. Nagar","Hyderabad")
df["City"]=df["City"].replace("Delhi Cantt.","New Delhi")
df["City"]=df["City"].replace("New Delhi Municipal Council","New Delhi")
df["City"]=df["City"].replace("Hyderabad M.Corp", "Hyderabad")
df["City"]=df["City"].replace("Tambaur-cum-Ahmadabad", "Ahmedabad")
df["City"]=df["City"].replace("Ahmedabad Cantonment", "Ahmedabad")
df["City"]=df["City"].replace('S.A.S. Nagar (Mohali)', "Mohali")
df["City"]=df["City"].replace('Panchkula Urban Estate', "Panchkula")
df["City"]=df["City"].replace('Mirzapur-cum-Vindhyachal', "Mirzapur")
df["City"]=df["City"].replace('Jawaharnagar (Gujarat Refinery)', "Jawaharnagar")
df["City"]=df["City"].replace('Jemari  (J.K. Nagar Township)', "Jemari")
df["City"]=df["City"].replace('Jam Jodhpur', "Jodhpur")
df["City"]=df["City"].replace('Bodh Gaya', "Gaya")
df["City"]=df["City"].replace('Chamoli Gopeshwar', "Gopeshwar")
df["City"]=df["City"].replace('English Bazar', "Malda")
df["City"]=df["City"].replace('G.C.F Jabalpur', "Jabalpur")
df["City"]=df["City"].replace('Ambikapur Part-X', "Ambikapur")
df["City"]=df["City"].replace('Azhikode South', "Azikode")
df["City"]=df["City"].replace('Bhagalpur (M.Corp)', "Bhagalpur")
df["City"]=df["City"].replace('Bad', "Badgam")
df["City"]=df["City"].replace('Badgam', "Budgam")
df["City"]=df["City"].replace('Nagar', "Anand Nagar")
df["City"]=df["City"].replace('Kalambe Turf Thane', "Thane")
df["City"]=df["City"].replace('Anand', "Anand Nagar")
df["City"]=df["City"].replace('North Lakhimpur', "Lakhimpur")
df["City"]=df["City"].replace('Chhota Udaipur', "Udaipur")
df["City"]=df["City"].replace('Balod', "Baloda")
df["City"]=df["City"].replace('Chandrapur Bagicha', "Chandrapur")

# %% [markdown]
# # Looking for City and State mistmatches

# %%
set(df["City"]).intersection(set(df["State"]))
# Out:
# {'', 'Bihar', 'Chandigarh', 'Pondicherry'}

# %% [markdown]
# # Setting columns with city as Bihar to Patna

# %%
for i in range(1,46044):
    try:
        if df["City"][i] == "Bihar":
            if df["City"][i] == "" or df["City"][i] not in capitals:
                df["City"][i] = "Patna"
                df["State"][i] = "Bihar"
            else:
                df["City"][i] = capitals[df["State"][i]]
    except:
        pass

# %% [markdown]
# # Resetting index values

# %%
df = df.reset_index()
df.drop("index", axis=1, inplace = True)

# %% [markdown]
# # Final Cleaned Dataset

# %%
df
# Out:
#              last_updated      tweet_id          created_at  \
# 0     2019-02-08 17:29:00  1.090000e+18 2019-02-08 17:28:00
# 1     2019-02-08 17:29:00  1.090000e+18 2019-02-07 05:10:00
# 2     2019-02-08 17:30:00  1.090000e+18 2019-02-08 10:18:00
# 3     2019-02-08 17:30:00  1.090000e+18 2019-02-08 17:29:00
# 4     2019-02-08 17:30:00  1.090000e+18 2019-02-08 14:19:00
# ...                   ...           ...                 ...
# 39869 2019-05-16 18:29:00  1.130000e+18 2019-05-16 14:55:00
# 39870 2019-05-16 18:29:00  1.130000e+18 2019-05-15 13:15:00
# 39871 2019-05-16 18:29:00  1.120000e+18 2019-04-26 14:10:00
# 39872 2019-05-16 18:29:00  1.130000e+18 2019-05-16 14:17:00
# 39873 2019-05-16 18:29:00  1.130000e+18 2019-05-16 09:41:00
#
#                                                full_text  quote_count  \
# 0      @DasComrade Sir any comment on modi's grand en...          0.0
# 1      Congress made Vemula national talking point ev...         47.0
# 2      BJP has been winning battles over the past mon...          1.0
# 3      @inclusivemind2 @Ark82876233 @BJP4India @Rahul...          0.0
# 4      Senior Congress leader @ManishTewari : There w...          0.0
# ...                                                  ...          ...
# 39869  A web page dedicated to tracking Rahul Gandhi'...          0.0
# 39870  Itâ€™s time to end the forever wars. But in th...        156.0
# 39871  The only phone number you need to reach any re...          0.0
# 39872  Bjp officer bearer, faked Assangeâ€™s endorsem...          7.0
# 39873  This is the real reason that Modi-Shah duo hav...         50.0
#
#        reply_count  retweet_count  favorite_count hashtags  \
# 0              0.0            1.0               1
# 1             72.0         2353.0            2353
# 2             12.0          513.0             513
# 3              0.0            2.0               2
# 4              1.0          159.0             159
# ...            ...            ...             ...      ...
# 39869          1.0           18.0              18
# 39870        318.0        16017.0           16017
# 39871          0.0           99.0              99
# 39872         30.0          463.0             463
# 39873        192.0          340.0             340
#
#                               user_mentions_screen_name       City  \
# 0                                            DasComrade   Guwahati
# 1                                                           Mumbai
# 2                                                          Kolkata
# 3      inclusivemind2,Ark82876233,BJP4India,RahulGandhi    Aligarh
# 4                                          ManishTewari  New Delhi
# ...                                                 ...        ...
# 39869
# 39870
# 39871
# 39872                                          PMOIndia  New Delhi
# 39873                                        IndiaToday
#
#                State Country
# 0              Assam   India
# 1        Maharashtra   India
# 2        West Bengal   India
# 3      Uttar Pradesh   India
# 4              Delhi   India
# ...              ...     ...
# 39869                  India
# 39870                  India
# 39871                  India
# 39872          Delhi   India
# 39873                  India
#
# [39874 rows x 13 columns]

# %% [markdown]
# # Final Dimensions

# %%
df.shape
# Out:
# (39874, 13)

# %% [markdown]
# # Inititalising Vectorizer, Sentiment Analyser and Stemmer

# %%
import nltk
"""nltk.download("vader_lexicon")
nltk.download("stopwords")"""
stemmer = SnowballStemmer('english')
vectorizer = TfidfVectorizer(use_idf = True, tokenizer = nltk.word_tokenize,stop_words='english', smooth_idf = True)
remove_punctuation_map = dict((ord(char), None) for char in string.punctuation)
sid = SentimentIntensityAnalyzer()
stopw = set(stopwords.words('english'))

# %% [markdown]
# # Text Preprocessing Unit

# %%
contraction = {"ain't": "is not", "aren't": "are not","can't": "cannot", 
                   "can't've": "cannot have", "'cause": "because", "could've": "could have", 
                   "couldn't": "could not", "couldn't've": "could not have","didn't": "did not", 
                   "doesn't": "does not", "don't": "do not", "hadn't": "had not", 
                   "hadn't've": "had not have", "hasn't": "has not", "haven't": "have not", 
                   "he'd": "he would", "he'd've": "he would have", "he'll": "he will", 
                   "he'll've": "he he will have", "he's": "he is", "how'd": "how did", 
                   "how'd'y": "how do you", "how'll": "how will", "how's": "how is", 
                   "I'd": "I would", "I'd've": "I would have", "I'll": "I will", 
                   "I'll've": "I will have","I'm": "I am", "I've": "I have", 
                   "i'd": "i would", "i'd've": "i would have", "i'll": "i will", 
                   "i'll've": "i will have","i'm": "i am", "i've": "i have", 
                   "isn't": "is not", "it'd": "it would", "it'd've": "it would have", 
                   "it'll": "it will", "it'll've": "it will have","it's": "it is", 
                   "let's": "let us", "ma'am": "madam", "mayn't": "may not", 
                   "might've": "might have","mightn't": "might not","mightn't've": "might not have", 
                   "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", 
                   "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock", 
                   "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not",
                   "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", 
                   "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", 
                   "she's": "she is", "should've": "should have", "shouldn't": "should not", 
                   "shouldn't've": "should not have", "so've": "so have","so's": "so as", 
                   "this's": "this is",
                   "that'd": "that would", "that'd've": "that would have","that's": "that is", 
                   "there'd": "there would", "there'd've": "there would have","there's": "there is", 
                   "they'd": "they would", "they'd've": "they would have", "they'll": "they will", 
                   "they'll've": "they will have", "they're": "they are", "they've": "they have", 
                   "to've": "to have", "wasn't": "was not", "we'd": "we would", 
                   "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", 
                   "we're": "we are", "we've": "we have", "weren't": "were not", 
                   "what'll": "what will", "what'll've": "what will have", "what're": "what are", 
                   "what's": "what is", "what've": "what have", "when's": "when is", 
                   "when've": "when have", "where'd": "where did", "where's": "where is", 
                   "where've": "where have", "who'll": "who will", "who'll've": "who will have", 
                   "who's": "who is", "who've": "who have", "why's": "why is", 
                   "why've": "why have", "will've": "will have", "won't": "will not", 
                   "won't've": "will not have", "would've": "would have", "wouldn't": "would not", 
                   "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would",
                   "y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                   "you'd": "you would", "you'd've": "you would have", "you'll": "you will", 
                   "you'll've": "you will have", "you're": "you are", "you've": "you have", "bharatiya janata party" : "bjp",
                   "inc" : "congress","@narendramodi":"modi", "pappu":"rahul gandhi","gandhi":"rahul gandhi", "@rahulgandhi":"Rahul Gandhi"}

def clean(text):
    text = text.lower()
    temp = ""
    for i in text.split():
        if i not in stopw:
            try:
                temp+=contraction[i]+' '
            except:
                temp+= i+' '
    text = temp.strip()
    text = re.sub(r'http\S+','', text)
    text = text.lower().translate(remove_punctuation_map)
    text = re.sub(r"[^A-Za-z0-9^,!.\/'+-=]", " ", text)
    text = re.sub(r"what's", "what is ", text)
    text = re.sub(r"\'s", " ", text)
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"i'm", "i am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r",", " ", text)
    text = re.sub(r"\.", " ", text)
    text = re.sub(r"!", " ! ", text)
    text = re.sub(r"\/", " ", text)
    text = re.sub(r"\^", " ^ ", text)
    text = re.sub(r"\+", " + ", text)
    text = re.sub(r"\-", " - ", text)
    text = re.sub(r"\=", " = ", text)
    text = re.sub(r"'", " ", text)
    text = re.sub(r"(\d+)(k)", r"\g<1>000", text)
    text = re.sub(r":", " : ", text)
    text = re.sub(r" e g ", " eg ", text)
    text = re.sub(r" b g ", " bg ", text)
    text = re.sub(r" u s ", " american ", text)
    text = re.sub(r"\0s", "0", text)
    text = re.sub(r" 9 11 ", "911", text)
    text = re.sub(r"e - mail", "email", text)
    text = re.sub(r"j k", "jk", text)
    text = re.sub(r"\s{2,}", " ", text)
    text = text.replace("bhartiya janata party",'bjp')
    text = text.replace("indian national congress", 'congress')
    text = text.replace("aam aadmi party", 'aap')
    text = text.replace("narendra modi", 'modi')
    text = text.replace("rahulgandhi", 'rahul gandhi')
    temp=''
    for i in text:
        if i.isdigit()==False:
            temp+=i
    text = temp
    text = text.split()
    stemmed_words = [stemmer.stem(word) for word in text]
    text = " ".join(stemmed_words)
    return text.strip()

# %% [markdown]
# # Cosine Similarity Function

# %%
def cosine_sim(text1, text2):
    tfidf = vectorizer.fit_transform([text1.strip(), text2.strip()])
    return ((tfidf * tfidf.T).A)[0,1]

# %% [markdown]
# # Preprocessing Tweets

# %%
preprocessed = []
for i in df["full_text"]:
    preprocessed.append(clean(i.strip().lower()))
preprocessed
# Out:
# ['dascomrad sir comment modi grand entri',
#  'congress made vemula nation talk point even though doubt case amp vemula dalit itself stop bjp make ramalingam case attain nation scale amp chang dalit discours take one remark pm modi make happen',
#  'bjp win battl past month bengal pm modi arriv win biggest battl announc warcri upcom war tmc elect modisonarbangla',
#  'inclusivemind ark bjpindia rahul gandhi bjp think cellchatumediacroniesscrit writer andbhakt crore speach give victori then late atal bihari vajpeyi much better shine india',
#  'senior congress leader manishtewari jpc definit next parliament parallel crimin investig process go go away rafal rafalenot',
#  'bc congress take kickback fr pp',
#  'rahulliecaught exclus former defenc secretari g mohan kumar tear rahul gandhi lie say no pmo interfer rafal price',
#  'expect meltdown congress elect wait till februari end bahut saar possibl hain ji',
#  'stori realli expos develop propaganda nation congress cudnt yrs modi sirji ask month abl hear terrifi stori jharkhand govt cudnt even solv basic issu last yrs',
#  'issu problem parrikar say defenc secretari resolv problemmatt princip secretari pm actual nail modi anyth els',
#  'forthefirsttim activ diplomaci pm modi india emerg leader intern platform first indian prime minist visit israel strengthen tie ageold natur alli year',
#  'modiunstopp speech made noisi kharg amp compani nervous confid speak way come easili one sincer amp honest job paplu taplu remain absent perhap nirmala ji arunji piyush ji s trailer prefer avoid modi ji s punch',
#  'piti state affair swachh bharat mission modi s kashi could understood fact even minist neelkanth tiwari also admit work mark flopswachhbharat',
#  'jim jordan remain best argument drug test member congress whitakerhear',
#  'rahul rahul gandhi ji use claim defenc minist manoharparrikar ji complet ignor rafaled note rafal file anoth lie expos rahulliecaught',
#  'modi govt make kitchen smoke free pmuy approx crore lpg connect provid poor india becom second largest lpg consum lpg coverag cleaner fuel ensur cleaner environ too transformingindia',
#  'bjp mp sh ianuragthakur launch campaign abkibaarpaar',
#  'prime minist shri modi today expos congress parti s fals fake campaign sever issu deliv outstand speech floor lok sabha congratul prime minist complet demolish opposit s claim',
#  'rafalescam saugataroymp loksabha today modishah duo destroy defenc backbon countri',
#  'howard univers built black offspr white member congress student main mulatto',
#  'forthefirsttim everi opposit come togeth defeat singl forc call namo everi crook aka mahabhrashtbandhan mahathugbandhan clueless newindia shine like never befor enemi fall like hous card modiunstopp modiforpm',
#  'india defenceministri sidelin parallel negoti pmoindia french parallel negoti import pm modi rafaled',
#  'incindia rahul gandhi next pm like modi retweet rahul rahul gandhi',
#  'erikacalvo mitchellvii aoc think anyon scare of like specif like quot propos like put forward make like total scari old white man congress or',
#  'shutdown made inequ wors enact polici enabl lowwealth famili buffer raini day build nest egg top prioriti new congress',
#  'shock un said isi biggest terrorist threat world time thought rss indian media lie us',
#  'nramind amp thehindu hitjob rafal use fakenew creat fake scam without fact discredit pm modi destabil nation amp stop defens procur time boycott mediapimpistaan lutyen boycottthehindu banthehindu',
#  'bjp up game right time anoth brilliant retort',
#  'govt lie sc that s entir rafal judgment question now rahul rahul gandhi',
#  'defenc minist nirmala sitharaman came heavili opposit particular aim congress parti rafal deal alleg rafalecongselfgo',
#  'ippatel modi essenti',
#  'need latina congress pressin',
#  'rafaled read paragraph parrikar admit pmo interf refrain blame modi derail negoti',
#  'complaint shashitharoor delhi court order fir republ tv amp editorinchief arnab goswami congress mp alleg illeg access document relat sunandapushkar death case tharoor face abet suicid charg matter',
#  'kerala rss inspir sewa bharathi build hundr hous kerala poor hindus thalachaikkanoridam place rest one head like hous kannur pathanamthitta palakkad various stage construct',
#  'congress doesn t want indian air forc strengthen put serious charg pm modi lok sabha modiparliamentspeech',
#  'rahul gandhi dear rahul gandhi hell amp congress would like tell us corrupt congress give arm forc one rank one pension year power',
#  'hindu clear crop import note para appear overreact rahul rahul gandhi base entir propaganda sovereign guarante note crop one',
#  'reveal mamata halt bjps rath yatra bengal operationrathyatra rahulkanw',
#  'srivatsayb shashitharoor ravishndtv sardesairajdeep indiatoday aajta wil u run news cri modi modi',
#  'sc govt submit detail rafaled decis make process govt affidavit sc no interfer govt rafal deal int mandat dac negoti deal defenceministri letter prove pmo run parallel negoti result sovereignguarante',
#  'rahul attack govt rafal base halftruth amp select media report not don t rahul s serial attack modi rafal withstand test scrutini rshivshankar rafalecongselfgo',
#  'pm modi thief stolen countri s rs crore rahul gandhi pakdagayamodi',
#  'ani one thing clear incindia tri hard cancel rafaled make forc weak again befit repli get incindia seat ls elect teach lesson',
#  'even peak advani abv bjp didnt much accept heartland west bengal today due modi peopl bengal support bjp enmass modisonarbangla',
#  'bengali write much ground bjp gain bengal latest column may dare put simpli bengali bit snooti a',
#  'dear invit applic travel grant support particip world congress malacolog august asilomar confer ground pacif grove california deadlin applic sunday',
#  'croplikethehindu yesterday met honour pm modi croplikethehindu',
#  'modi one thing congress done govern chhattisgarh separ state ayushman bharat scheme polit health peopl',
#  'nimh explicit forbidden congress conduct research whether gun control decreas number suicid mqsciencemeet',
#  'all pm modi blister speech yesterday lesson bjp spokesperson tv debat communic',
#  'bhai ise bhi fact chek kar leng congressi slave no rahul rahul gandhi didn t say don t trust me',
#  'egg face congress keep one anoth everi attempt tarnish modi govt end dead end noth find fault with seem think modi govt like fortun good govern thank nsitharaman',
#  'look like act ag whitak job doesn t give shit congress smart man',
#  'congress opposit parti sooo rattl know modi come power again land jail next five year henc r tri creat fals scam like rafal never exist rafalecongselfgo jaypandablackmoney',
#  'congress vp rahul rahul gandhi prais zeenew report ask question jay shahzada say daromat must watch',
#  'vs croplikethehindu today headlin toimumbai job vacat tall claim job made pm modi loksabha yesterday laugh today howsthejob',
#  'wonder david pecker lindsey graham could also blackmail member congress compromis amazon ceo jeff bezo accus nation enquir extort intim photo',
#  'blainejo natashabertrand subpeona him make invok execut privileg cite contempt congress he is act ag day right',
#  'dewa youth wear shirt bhopal congress ralli say choukidaar',
#  'whose tune rahul rahul gandhi danc rahulkabaapchorhai',
#  'prove bjp led narendra damodarda modi care two hoot democraci bjp flush slush fund bjp use ill gotten wealth possibl rafalescam ongcscam etc devast effect undermin democraci',
#  'countdown winfocus world congress dubai',
#  'congress incindia believ farmer india backbon countri economi henc problem redress prioriti basi vachankipakkicongress',
#  'great articl yesterday climat scienc discuss first congress sinc read keep mind kid face beyond base polici make right freakin now',
#  'vazeindian constitut institut systemat destroy credibl come stake use vendetta polit opposit modi regim prior elect gain browni point fool peopl',
#  'notic racist sweat factori combat black member congress he is white folk',
#  'merabharat pathet thing communist congress use muslim communiti good push communiti toward destruct',
#  'disingenu congress member rep jim jordan',
#  'congress men women let answer rude are whitak',
#  'diamondandsilk quarter drug test year mental evalu congress member must',
#  'madhya pradesh walk congress vachankipakkicongress',
#  'bjp may may oust india cannot defeat sanghi fascist forc till parti recognis beefcowslaught ban india equival blasphemi miscegeni law amp scrap them amp criminalis honour crime incl love jehad hate campaign',
#  'member congress support aoc absurd green deal scienc project immedi disavow air travel meat immedi prove board',
#  'chowkidar clean scare jpc chowkidar negoti rafaled pass mod pakdagayamodi chowkidarhichorhai rafalescam',
#  'want wit priyanka vs modi battl varanasi abp newscvot survey read priyankafactor',
#  'wtf manag judg don t case sabarimala ayodhya chidambaram s stay pappu s bail cancel',
#  'modi coward psycopath',
#  'patti understand nda tendwamo mboli man',
#  'discuss hdkumaraswami air audio clip bjp strategi karnataka promo abnliv',
#  'popular demand huge number one guy ask it poll open onli bjp support vote modi',
#  'nramind effort commend modi form gov may',
#  'grim stori pm modi startupindia kill angeltax extortionist despit specif assur commit given pm minist who is behind brutalis startup piyushgoy sureshpprabhu',
#  'mean pmoindia interf rafaled need interfer this plant ani modi govern invit troubl langamahesh rohinisgh iamnarendranath dillidurast',
#  'gandhi crop document small thing indira crop feroz rahul gandhi life kept surnam rajiv crop sikh keep power sonia tri crop nation kalam caught her rahul tri crop bjp end crop cong rahulliecaught',
#  'this danger game congress play play corpor game put asid nation interest object shock defenc minist nirmala sitharaman speak media sharp speech parliament rafal issu',
#  'congress get number import thing world amp idea like women empower wait indefinit person gainssh think muslim men domin femal counterpart appeas maximum amp ladi willi nilli vote per dictum',
#  'saurabh anoopmaheshwar cast vote bjp vote nation develop cast vote khangress vote rahul gandhi famili develop',
#  'news updaterahul rahul gandhi drunk ml water aquafina ltr bottl water remain bottl',
#  'corapunzel repstevechabot who is tire old dement men congress',
#  'modi attack mamata wb say dream becom pm cant control violenc wb serious modi allow ask ppl brutal murder genocid cm gujarat',
#  'pm modi welcom black flag assam merabharat biriyaa biriyaamedia assam assamnew citizenshipamendmentbil',
#  'priyankac flashback priyanka chaturvedi said tmc sharda chit fund scam parti congress hitler didi perfect exampl opportun lol',
#  'pm modi greet anger resent black flag guwahati earlier today protest oppos citizen amend bill voic peopl heard daromat',
#  'bjp goon attack arvindkejriw usual delhipolic noth vs',
#  'thehindu alway anti hindu sinc crypto nram taken it gone mad bcz cannot digest fact modi expos corrupt chrislamist msmcroplikethehindu smitamuk mayamadhava drprasadva ckpvignesh isvelan',
#  'tajinderbagga like it chowkidar pure hai rahulkabaapchorhai',
#  'it s first time histori countri cm sat dharna shield corrupt loot poor hardearn money mamata didi afraid investig chit fund scam pm modi modisonarbangla',
#  'governorship candid progress congress apc river state pastor tony cole declar support unshaken faith the',
#  'check mani first womenempower regist modi govern modi pmoindia forthefirsttim',
#  'question i d like whitak answer part whitakerhear communic member congress staff prepar hear and so who',
#  'also believ rahul rahul gandhi track record lie ask shehzadind lawyer rafalecongselfgo',
#  'bjpindia rahul gandhi thug life pm modi',
#  'gorwayglob pbhushan aaplog nail it almost even catch modi shoot soldier hold hand hafiz saeed stand nation flag parti feast beef kebab media amp bhakt still ignor',
#  'join twitter recent colleagu said mam get verifi blue tick cos twitter believ bjp member bigot bias basic liar also ad know may lose exist verifi status fb page',
#  'littl shiffi need reveal enough releas fisa mr presid dem propos unpreced amp unwarr crime need address amp they re pictur below let indict go forwardlet s see mani congress expos',
#  'break sourc jp reveal actual reason behind rafal scuffl congress leader took commiss eurofight robert vadra also receiv plot germani',
#  'kirronkherbjp fgautier thehindu rahul gandhi modi bhakt dumb import dm repli tri away shoo away charg level mod modi state overreact mod clarifi matter pmo modi monitoringnot negoti',
#  'vote definit bjp convinc other aapian amp congii particular vote bjp well',
#  'old photograph use project show strength pm modi west bengal ralli via altnew',
#  'modi today confid man sure he is win one care he is lose',
#  'person peon priyanka ppop',
#  'hikerdogduo adamschiff investig tax payer fund hush fund use congress silenc dirti deedswher cri',
#  'parti call armi chief sadak ka gunda sociopath call kargil bjps war famili refus celebr vijay diwa mani mani year liargtgt rahul gandhi',
#  'gop congress peopl freak whitakerhear one word you benghazi motherfuck',
#  'when there is wide spectrum debat issu public play role public need call member congress say this someth care about aoc via cnn public support greennewd',
#  'exclus congress rafal attack bring modi power again say defenc minist nsitharaman',
#  'last chanc let us know would like see world fisheri congress email idea suggest jan wfc worldfishcent',
#  'jorellana jeffdeist reelectnydia thecjpearson aoc peopl would never make privat sector reason stay congress forev plus pensionsbenefit get upon retir basic noth offic',
#  'biggest concern vis vis rafaled dent imag modi ji beyond repair brought credibl pmoindia zero level jai hind',
#  'let legaci exampl us all patriot serv countri came congress simpl mission help other never waver commit send thought famili repdebdingel',
#  'pakdagayamodi chowkidar like bachao bachao simpl aircraft math bhaktoo compar mms vs modi number rafal mms modi price per rafal mms cr modi cr math let know comment chor',
#  'billionair gop donor demand republican puppet congress hand massiv tax cut gop lawmak deliv',
#  'rep aoc call congress cut fund ice border patrol end abus treatment immigr',
#  'tell congress cosponsor save pollin act savethebe monarchbutterfli savethepollin',
#  'ncepl block nh dwarka expressway connect what is signific dwarka expressway cannot connect nh blackday new gurgaon bjp cmohri modi mlkhattar pmoindia nitingadkariin timesofindia ndtv redfm radioc',
#  'snippet cp rahul gandhi press confer rafal scam today pakdagayamodi rahul gandhi priyankac withpgv zohebsh',
#  'rahul rahul gandhi use malici edit dissent note publish hindu spread half lie rafal',
#  'delight privileg meet congress gen sec priyanka rahul gandhi vadra ji aicc team mahilacongress thank sushmitadevmp ji',
#  'namo group share video wa muglikar amitmalviya',
#  'massiv failur sbi merger nda govt clamour yet anoth bob vijayadena bank blind realiti sorri state affair bank merger antipeopl retrograd reform govt wake up pmoindia soumyadatta stopmerg savepublicsectorbank',
#  'sell out modi treat us like third shoe rafalescam pakdagayamodi',
#  'pm s speech fine comparison year congress rule n month modi sarkar',
#  'whenev hous rep congression committe refer fellow member congress the left know he is good rep good servant republ repandybiggsaz whitakerhear',
#  'hindu notori newspap publish half bake news day modi speech parliament look strateg time public articlethi show newspap sold soul dynasti linah baliga s post',
#  'go chang world take everi singl one us stand togeth demand congress take climat chao peopl power it s time greennewd',
#  'modi interest pamper croni corpor modi alway neglect poor worker cheat fake promis workersagainstmodi',
#  'modi support get work pikettylemond piketti pleas look within govern believ soak rich punit taxat redistribut',
#  'modifiedvika modi',
#  'massiv show strength bjp odisha yuva morch today bhubaneswar rozgarmaguchiodisha',
#  'tmc mamata corrupt parti lakh peopl cheat saradha scam much loot rose valley scam modi govt take action scam whi is mamata stop him modistopschitfundscam',
#  'vinirish rahul gandhi brother sqn nda ashok senior us arun int corp coursem rgds',
#  'column john dingel devot institut congress last legaci write cokierobert',
#  'whitak ought held contempt congress',
#  'hello bjp',
#  'doubl selfgoal modi teleprompt guid ralli fail take rafal top tend n ram say parrikar role need separ investig pakdagayamodi',
#  'pm modi face black flag protest peopl assam today show resist strength resili peopl assam mani black flag greet wherev go scrap communal citizenship amend bill',
#  'watch bjpindia broadcast pm modi address public meet mainaguri west bengal modisonarbangla',
#  'five obfusc rafaled four simpl question modi govern must answer devangshudatta replug',
#  'bjp cell work rahul gandhi shashitharoor pmoindia modi sushrimayawati yadavakhilesh',
#  'mod call modi bluff without even scintilla ambigu prove beyond doubt pmo led modi embroil corrupt rafal deal khushsundar inctharoorian drshamamohd laksrtn ashoswai',
#  'vote congress',
#  'jesuischarli nitingadkari modi harshkkapoor drsarangbani saliltoday prettypadmaja durgamenon debashishhit sagenaradamuni desertfoxi akkhanna take posit congress admit bjp good work infrastructur deni anyth good that news correct report mate',
#  'attend south gujarat youth congress ob meet regard hon ble congress presid rahul gandhiji rahul gandhi visit valsad th fab',
#  'singl tweet republ rafaled expos hindu come propaganda show loyalti toward chiwkidar aakhir arnab bjp ka namak kahta hai',
#  'bjp karyakarta remov flag communist tripura happen west bengal pm modi modisonarbangla',
#  'rahul gandhi question modi amp nsitharaman did air forc amp defenc ministri object bypass origin rafal deal',
#  'useri illeg hell get fing gop congress amp wh',
#  'run world girl congrat fab new femal us congress bossi gingerbread girl thursdaythought midterm',
#  'charupragya ji congress rafal like dog tail seedha hona hi nahi hai inko matter long tri keep straight',
#  'forget modi open challeng rahul gandhi debat rafal i will make cri min rafal dead hors dead dream stop beat itrafaled darpokmodi nahi darpokrahul hai remain absent modi speech parliament',
#  'trillion dollar indian leadership s vision express day ago need protect realis decad ahead statement nda allianc rbi step plate today excel teamwork',
#  'congress take bike ralli karnatka karnatakatrustsmodi',
#  'mid term poll goa possibl prithviraj chauhan lokmat goa pratapsinghran felicit prithvirajchauhan congress',
#  'fact modi gave cr anil ambani compani wealth grow go bankrupt croplikethehindu',
#  'case governor virginia state would execut babi birth defend digniti everi person ask congress pass legisl prohibit late term abort children feel pain mother womb',
#  'crystal clear prime minist stole rs cr money amp gave anil ambani rahul rahul gandhi rafal this rs crore could given famili ad',
#  'think local cm give never vote bjp observ recent tg assembl elect rural elder vote trs either make scheme central fund it',
#  'ani sanghe bhakt alreadi think rahul rahul gandhi pm india look they nmatia expect rg speak various aspect modi busi congnehrupatel check nmatia s tweet',
#  'rahul gandhi congress jhooth ki factori claim lac peopl attend rahul bhopal ralli realiti congress worker attend ralli congress jhooth ki factori rahulkabaapchorhai',
#  'idea propos vijay mallya nirav modi mehul choksi bjpparti',
#  'big break bsybjp caught audio clip say modiamith shah manag suprem court judg offer bribe operationkamala bjpbribeexpos chowkidarhichorhai karnatakabudget',
#  'rahul rahul gandhi challeng pm modi debat capac pm candid mahathugbandhan none allianc parti will accept pm candidatur darpokrahul',
#  'spectatorindex rahul gandhi see india stand today term global stand congressmuktbharat congress modiunstopp',
#  'alway vote bjp you',
#  'spectatorindex indian bank account result implement pradhan mantri jan dhan yojana modi govern pm s visionari leadership inclus growth gradual show result',
#  'rememb act ag whittak testifi congress let us see respect sir get ask question',
#  'look forward work congress ensur justic involv individu fair chanc abl access qualiti educ train pathway amp incarcer see reconnectingjustic brief here',
#  'edkrassen whitak act like juvenil delinqu fool he is caus end career congress slap legal problem',
#  'thread post earlier congress run paid ruthless outsourc misinform war sm amp msm promot fakenew fakenarr mislead amp divid voter pleas click link amp rt tweet it',
#  'vccirclepremium innumb midsiz compani job creator modi year',
#  'pallavighosh yes rahul s speech powerfil shit abus like sadak chap ruffian',
#  'presstitut ask question modi debat whether countri belong muslim amp dalit hindutva take countri to crime dalit blame center amp higher cast hindus',
#  'mistak happen bad intent rw account collud congress ecosystem ideolog mind corrupt rw mistak happen one excus technolog driven biasef employe good select ppl',
#  'onli solut bjpindia rajnathsingh amitshah modi nsitharaman piyushgoy arunjaitley pmoindia hmoindia send mpsmlas ward across nation meet peopl listen person spread good develop work expos congress lie',
#  'dingel serv near year congress play key role pass endang speci act clean water act major propon civil right act creat medicar',
#  'rahulliecaught answer peopl countri suprem court prove credibl dr sambit patra nation spokesperson bjp',
#  'modi start address elect ralli brain don t say don t say don t say don t say don t say don t say don t say don t say don t say don t say don t say don t say don t say don t say modi mera yaha se khaa rishta hai',
#  'us ambassador ask question abt lashkaretaiba amp prime minist aspir kaul dattatreya janeudhari rahul gandi respons said hindus greater threat yes hs love nation amp hindu cultur danger battl harden jihadi grps militari train',
#  'congress purchas fighter jet tenur modi govt buy rafal rahul tri everyth deal get cancel say air forc offic this crore given die plane crash cruel joke',
#  'jaybhadrakali timesnow rshivshankar thank good congress govt hindi heartland least saniti prevail riot would start bjp still rule there',
#  'rahulliecaught congress peddl kind lie today resort use newspap spread halfbak lie show desper defenc minist nirmala sitharaman',
#  'pm modi face massiv protest guwahati black flag shown protest',
#  'know mani indian pilot mig kill mig tube engin one end pilot other aerodynam consider fli coffin plane induct iaf congress pleas russian rahulkabaapchorhai',
#  'time war presid call nation emerg without congress us war isi amp drug smuggl',
#  'rahul question inflat pricegovt hide behind configur changelat reveal same rahul question object defenc mingovt replylat reveal def min object new deal scs decis base nonexist cag report rahulliecaught',
#  'asg fake news kapil sibbal spread modi mediami appeal twitter userthat modi laat maar bhagao',
#  'vanitajain modi rameshbjp ankkinegi mini soniagurnani nishant abbjp aniljmodi gauravmodifi abhish easypeezytweet cantstopulovinm congressdahan deanarayan vidudalaprasad onlinerajan invinciblebabu modiunstopp namoagain modi bcos love countri dont want go hand traitor thug',
#  'someon pleas tell lenni amp squiggi congress actual got elect time repswalwel amp repadamschiff head back stori hollywood career heck they have even got true life action figur cmon duke nuke em amp schiffforbrain us favor',
#  'john dingel warn congress deregul bank dad help write glasssteagal parti ignor him pretti prescient stuff',
#  'big issu rais nramind big expos let enumer one modi pmo illeg open parallel negoti franc illeg crimin offenc',
#  'pleas send person messag modi ji mani peopl possibl',
#  'modi govern misguid sc',
#  'aoc sinc believ sign bill let explain someth ya stupid bill doa miracl pass congress doubt presid veto monstros justic demonrat forc behind u miscalcul thing two lol',
#  'dear rw bjpnda support bewar everyani all conspiraci theori spread bot illegitim msm overignor comment negativ complet spread good work pm team we bring cr wattag light',
#  'congress parti feel sad pathet condit womena claimsbut surpris fact dat tri listen problem ladi who realli want justic parti worri mulla these tripletalaq aicc minor depart',
#  'bjpindia rahul gandhi thread expos congresscambridg analytica devious plan make rahul rahul gandhi accept amp project upa gradual use fake account oper pakistan target amp divid hindu voter pleas rt share max',
#  'with legisl pend chamber congress next logic step lawmak sit circl final hash differ via forb tomangel',
#  'godspe johndingel dedic public servant gracious gentleman twitter laureat grate servic michigan john dingel longestserv member congress die via freep',
#  'desimojito succeed convert aap vote bjp',
#  'kamallochanm bjpindia media alway tri creat hype around gandhi confus around bjp strategi',
#  'sagarikaghos pmoindia journal sidelin parallel negoti congress pidi media propaganda news import pappu rafaled croplikethehindu',
#  'matt gaetz clear cut exampl conserv corpor amp evangel extremist want manag govern congress peopl see amp hear expect see amp hear ignor peopl actual say',
#  'desimojito famili extend famili vote bjp bold n open ask ppl vote bjp make sure bjp take lead booth aartic',
#  'contest poll either congress rjd ticket bihar deputi cm sushil modi dare bjp mp shatrughan sinha',
#  'today ask nine question rahul rahul gandhi robert vadra show nine email dr sambit patra nation spokesperson bjp address media priyankabacksvadra',
#  'hapless cbi plung headlong one controversi anoth modi govern came power',
#  'former niti aayog vice chairman take modi critic hand on prais vajpaye pm modi polici',
#  'ex defenc minist manohar parrikar respons pm deliber crop hindu nramind give rahul gandhi anoth shot pm rafaled pappus dismay lie throw shortliv pappufirpakdagaya rahulliecaught',
#  'modi guwahati protest show black flag slogan like modi go back scrap citizenship amend bill joi aai asom heard larg group bjp support amp minist sidhartha bhattacharya amp pijush hazarika seen stand near aasu protest',
#  'anzsana alan tidwel director canzp georgetown present mr smith goe australia short histori visit australia member us congress clarkcenteroznz utaustin aushist',
#  'thelinguist correct tweet aartic block someon solutionaccept grammat mistak amp unblock thelinguist nobodi tell vote bjp',
#  'expos thehindu rafaled discord mod pmo lay bare lie bjpindia bound come out prime minist cannot duck question wrongdo undermin author corrupt',
#  'exsecular aninew authackeray lacharsena hope peopl vote bjp bmc elect kickout lacharsena',
#  'repjerrynadl cover up like mani member congress terrifi whitak',
#  'greennewd faq we financ invest green new deal way paid origin new deal world war ii bank bailout tax cut rich amp decad war with public money appropri congress aoc',
#  'central project renam bengal bengal project peopl bengal alreadi awar modi slowli bring chang bangla modisonarbangla',
#  'waltshaub repdougcollin whitak seem want run hear fiveminut rule subject matter etc consist execut branch believ congress defer it odd rep collin believ forefath want king say',
#  'everyon kisacor microbiom congress wish two blog post tweet combin day day enjoy mbcongress',
#  'divin justic time one side honest pure soul like parrikar suffer devious dishonest leach like sonia amp rahul go strong',
#  'i serv congress longer anyon here s fix it abolish senat public fund elect',
#  'maureenmano hope haven t seen indic it hope justic kennedi s son time deutsch bank investig would help congress also look it',
#  'mkraju gottalaff contempt congress',
#  'forthefirsttim chief editor rahul gandhi creat fake narrat ist letter half bake inform def secretari nd part omit omit parrikar repli letter slice amp dice suit rahul gandhi narrat full parrikar letter',
#  'bjp baseless alleg congress sc alreadi gave clean chit respect sc media document neither present sc examin it bjp see afraid poor person poor background challeng them',
#  'yrs congress major legisl twitter game artsychica kfaunt spectnscript questphys gotta laugh keep cri ripjohndingel',
#  'partyvillag one dissent best plane time lot countri bought it kick back part congress true retro fit incompet hal ruin mig henc lot accid like recent mirag plane lost land gear take off blame congressh',
#  'us congress member repmaxinewat if worldbank board ultim vote confirm mr malpass bank s climat financ agenda increas essenti element global econom cooper also threat',
#  'jhasanjay youthcongr corrupt modi loot india chowkidarchorhai votebjpout',
#  'forthefirsttim travel airplan rich modi govt made air travel afford udan peopl travel airplan ac train udan',
#  'earlier use say jampk mean jammu kashmir two region today modi decis it s jampkampl mean jammu kashmir ladakh don t know media broadcast big newsjai hind',
#  'spanishol idea wealthi and power member congress are look wealth gain sinc offic',
#  'tajinderbagga ceodelhioffic zeenew avasthiad manishvermaman immanishpandey parveenbangw psahibsingh rcd call min back frm prsn clmng rpsnttve aap told tht name hd bn remvd frm voter list instrction bjp cheap polit arvindkejriw',
#  'johncardillo exclus video releas infowar minut clip leak member congress',
#  'rangat hinduso life less precious liber msmso outrag except pmk bjp parti even condemn bjp talk meet msm everywher india cannot expect film industri speakmost like individu might speak',
#  'sadden hear rep dingel s pass lifelong sportsman dedic conservationist work decad protect wildlif advanc made congress conserv mani count grate servic we will miss dear',
#  'half lawmak congress even fraction human empathi aoc has countri would complet differ place right now someon genuin care human be want fight me',
#  'rahul rahul gandhi rahul gandhi parrot china anyth govern job know china figur list',
#  'rt vote bjp',
#  'millenni take congress pt katiehillca',
#  'prakash group alway modi bachao abhiyan chang fact interf',
#  'stevesilberman clarajefferi mose supermani also patriarchi man koolaid right respons metoo era blue wave women congress abortionwoman right choos right',
#  'economictim rahul gandhi realli gut document genuin prove modi wrong whole india support you turn you resign congress go amp file case court open challeng you modi',
#  'two month die john dingel serv congress longer anyon publish piec fix it',
#  'what use degre sell egg job crisi modi',
#  'white hous miss deadlin congress turn heat answer journalist jamal khashoggi kill saudi crown princ role via abc news',
#  'emptywheel whitak gop obstruct black congress men women speak',
#  'doug collin went night school take class lindsey graham take upper hand congress committe meet',
#  'haha bjp cell kill it boht hard',
#  'teamcongress understand it s difficult guy go meet peopl introduc congr support rahul sir support peopl mock you so introduc neutral ppl intellectu liber way still job',
#  'trollmodi modi wave assam black flag',
#  'oppos nota nota mean victori ukfound incindia rahul gandhi congress ilk defeat cost save bharat sanatan dharma',
#  'oh someon pleas check grammar must rahul ka baap chor thaa hai naa',
#  'watspn predictionman he is also paid least one know use tax payer money congression slush fund establish thing think moment congress actual fund pay sexual harass charg sick money',
#  'tamil nadu becom like bogi adityanath upmodel govt puppet modishah',
#  'embarrass hilari accord ttindia spoke to civilian around none allow area day modi wave imaginari peopl benefit ani camera modiwavestomountain',
#  'mandela likewis initi advoc nonviol resist join south african communist parti cofound umkhonto sizw arm wing african nation congress due sharpevill massacr a blatant exampl state fascism',
#  'drpratiksha rahul vacanc somebodi like me veronica out',
#  'vote bjp you',
#  'booth committe prepar meet anand congress offic',
#  'biggest fake news year peddl hindu rahul gandhi rahul gandhi croplikethehindu',
#  'in john dingel longestserv member congress histori die age champion univers health care cast vote hous help pass medicar obamacar',
#  'insid trade congresmen made illeg by wait it congress',
#  'pmoindia nitingadkari officeofng upgovt fantast road trip meerut ghaziabad km hr thank modi jee sri nitin gadkari much traffic polic open jam yogi jee kuch dhyan dijiy yaha bhi elect ane bale hai',
#  'put knowledg test thursday lincoln famili mani sibl abraham lincoln have mani term congress lincoln serv robert lincoln attend famous prestigi colleg one lincoln children die white hous',
#  'oh ho ho ho look like bisexu sorceress arizona littl independ rest femal coalit kyrstensinema go need moloch power make first trimest let us hope blood thirsti congress women abort her',
#  'jeffpick wrote what is go infanticid debat congress bornal paincap via erlc',
#  'rahul rahul gandhi want soldier die plane crash noth less terrorist mindset man prime minist candid congress rahulliecaught croplikethehindu',
#  'whi entir congress absolut concret tie jewish nation fact it s mani fund entir career okay normal peopl can t peopl white nationalist',
#  'sidmtweet ah secret hide rafalescam out way modi amp shah manag thing pakdagayamodi',
#  'took destruct whole year end real charact corrupt part india bjp come out like n ram said moment real journal return th pillar democraci come back life rafaled',
#  'john dingel pass last night deepli sadden truli one finest peopl ever known someon chang million live column wrote year ago announc retir congress',
#  'notic congress beat bjp game tri ride movi bad movi end selfgoal laugh stock see congress turn yuvajosh gullyboy azadi that is edg gop year exp',
#  'must watch see realiti pm modi ji asset live life devot sincer countri blood boil scoundrel khandani chor moron born foreign ladi call hardwork amp devot pm chor modidobara',
#  'forthefirsttim india script new chapter histori space explor success launch record satellit one go space research amp develop achiev new mileston support modi govt',
#  'hmmm note come june definet disappoint sure back basic chaiwala pakdagayamodi darpokmodi rafaled',
#  'reason congress shut allow strengthen arm forc',
#  'financ minist piyush goyal plan entertain industri bjp leader actor paresh rawal kirron kher smile how is josh now budget budget sirpareshraw kirronkherbjp urithesurgicalstrik howsthejosh',
#  'kevinliptakcnn acosta incred whi treat congress like demean law maker',
#  'rahul stori boy meet girl stori one rahul embrac happi respons take mainsehum ka kadam intuit visit',
#  'aartic vote bjp',
#  'mrsnakela anyon will say loud hall congress hous peopl unborn child right made imag god alway vote courag leadership best',
#  'rahulliecaught part cut letter rahul rahul gandhi use make rafal parallel negoti attack pm modi',
#  'funder matt whitak contempt congress prosecut',
#  'in matter defenc deal role congress amp bjp clean like bofor congress govt question r rais bjp govt alleg scam rafal deal far given satisfactori answer mayawati oct',
#  'share max aap rajya sabha mp sanjayazadsln question bjp pm modi rafaled irregular corrupt demand joint parliamentari committe jpc probe alleg corrupt cc arvindkejriw',
#  'aartic alway modiji amp bjp incompet dynast duffer',
#  'yrdeshmukh modi bhakt see word anti',
#  'crown princ rahul gandhi will join hand anyon corrupt even mean go troop time push back let s continu build corruptionmuktbharat narendramodi modiagain',
#  'sumanthraman don t agreethi time dmkcongmdmk sweep admkbjp got admkinc got while jayalalithaa alivecurr aiadmk govt discredit one i don t see aiadmk get anyth gt kartipc',
#  'everybodi shift focus bs yedyurappa s audio leak heard say worri sc modi amp shah fix judg noth scari this need immedi probe audioleak',
#  'know inspir peopl courag determin grit abil take risk rahul rahul gandhi surpris join student protest jnu face flak all parti',
#  'believ awwwww modi kid loot nation read pmo direct negoti rafaled despit protest indian defenc ministri desh droh',
#  'robert vadra karti chidambaram senior congress leader p chidambaram face ed money launder case',
#  'immens crowd mayanaguri await pm shri modi show love peopl bengal him modisonarbangla',
#  'one side pm say believ loktantra side promot bhakt bhidtanra entir bjp member bhidtantra vs',
#  'rahulliecaught exclus no money given offset partner say air marshal sbp sinha tear congress rs crore given anil ambani modi govern lie',
#  'vote bjp you',
#  'upa govern came attack didn t label bjp desh ke dushman look like modi realli walk hotter coal call opposit enemi state desper pakdagayamodi rafaeld',
#  'miami best eat drink weekend rum congress valentin bar crawl galentin brunch experiencemiamibeach miamibeacheat miamirumcongress mandrakemiamibeach foodandwin',
#  'freedom fighter ever dream india arvind kejriw car attack outer delhi men carri bjp flag',
#  'rememb congress said go start pay intern hous intern still wait paycheck',
#  'us hous s energi amp commerc committe hold first hear year address climat chang statement committe show congress use energi effici climatesolv tool',
#  'snehasneha smitaprakash see right was wait see desper congress becom prove narrat correct never ever explain anyon offset are tot joint ventur relianc defenc dassault aviat in',
#  'live matt whitak testifi congress via youtub',
#  'john dingel legend congress legend twitter tweet turn book rest peac king',
#  'energi wish list congress energyeffici',
#  'know call habitu lie day back rahul baba clear mention talk rafal issu met former defenc minist manoharparrikar ji today deni convers held regard rafal day hypocrisi',
#  'met senior enterpreneur yesterday hard core modi believ amp support said modi can t deliv india s futur arrog listen other talent prefer loyalti talent team vote bjp risk india s futur',
#  'the modi govern s overrid desir show rapid pace toilet construct distract object better health outcom plan sustain manner thus wast million taxpay money public jumla flopswachhbharat',
#  'barbarabox subpoena butt hold contempt congress',
#  'learn th congress legisl branch feder govern compos senat hous repres',
#  'delhi cms car attack narela area kejriw gone inaugur develop work unauthoris coloni narela aap alleg attack bjp worker',
#  'vivekagnihotri put poll vivekagnihotri as debat modi rahul gandhi mani mark modi get',
#  'mani women serv congress mani men shut fuck up',
#  'modi refus wear scull cap entir secularislamist nexus outrag like hell secular man wore skull cap accept offer allah skull cap not secular irrelev kafir kind gestur reciproc',
#  'funder angri control congress',
#  'operationrathyatra mamata allow bjp hold rath yatra bengal faith state polic ask raghav live',
#  'rahulkanw indiatoday bjp payrol indiatoday one mediaoutlet swallow part taxpay money inr crore pr watch see gargac',
#  'feel inspir largest group women ever elect congress same we re excit even made tshirt',
#  'ncbn hdkumaraswami modi hatho desh ko bachao save nation save democraci',
#  'joycewhitev whiskyfrank ahol seem realiz answer peopl congress present repres major',
#  'tmc gain lot trinamool tolabaazi tax syndic tax levi peopl bengal pm modi come abolish tax make life easier peopl bengal modisonarbangla',
#  'tavleensingh seat parliament even mahagathbandhan doesn t consid rahul rahul gandhi mascot prime minist india get debat though much rank perhap nirmala sitharaman smriti irani could consid',
#  'amitabhafirst vikramwkarv guriqb pashasehg olivegrin akmpnm punamindian manmohan kayjay woodcheat sandythapar chatythecheetah vigodoon warriormukul defenceminindia nsitharaman pibindia adgpi iafmcc indiannavi spokespersonmod hqidsindia brigmahalingam kakarharsha singhnavdeep jaykaul jessisajan bsrangi cmseth justsingh majorpoonia neeraj smritirda drsubhashmo tksapru genkumar arunbajpai sushilbhasin bjpindia pmoindia modi coltekp colcharanjit ajitbhind colbharat majdpsingh rwac ashokkmrsingh vedmalik pradeep never understand attitud indira rahul gandhi remov orop kept vote congress sonea rahul gandhi never implement orop amp kept cr budget sideshow modi implement amp gave vr till hv prob bcos gave demand',
#  'whitak refus meet congress defi subpoena arrest go jail contempt congress fun fact contempt congress fall purview presidenti pardon',
#  'journalist raipur wear helmet safeti bjp leader',
#  'corrupt dynast rahul gandhi engag number congress journalist peddl lie abt nonexist corrupt rafaled never succeed lie crook pm modi like nail wait hit coffin retardrahul gandhi',
#  'rahul maa mera baap kaun hai sonia tera baap chor tha cough rahul i m ask dad husband sonia chup chaap ja wake night rahulkabaapchorhai rahulliecaught rafaled',
#  'congressman john dingel s countless accomplish legaci longestserv member congress alway rememb thought wife repdebdingel famili friend difficult time',
#  'across india one say word chowkidar crowd echo chor hei congress presid shri rahul rahul gandhi said merasamvidhaanmeraswabhimaan',
#  'world s top scientist warn year transform economi amp avert climat catastroph togeth w aoc senmarkey justicedem amp brought plan congress match urgenc scale crisi add ur voic',
#  'alphamaximus aranganathan rahul gandhi journalist cannot counter him trust left scratch head keep hear random crap speak presser god know what is snort whatev imag makeov congress happen due priyanka entri flush',
#  'congress put huge dent name modi continu confront him rahul rahul gandhi merasamvidhaanmeraswabhimaan',
#  'anoth sixersofmodi ji till administr center jampk modi govt today separ ladakh kashmir amp ladakh separ administrationsdivis thank honor pm modi ji welcomedivisionstatustoladakh',
#  'desper even rahul gandhi standard modiforpm rafaled croplikethehindu',
#  'hate modi opposit begun hate nation leader go london press confer show india bad light pm modi',
#  'aasu member black flag torchlight protest mark pm modi s visit guwahati',
#  'europ gdpr cut cybersecur research law enforc opioid activist antipiraci group global domain name databas new tech lobbi push hard congress reopen internet white page',
#  'rep dingel s servic congress predat cspan year',
#  'percent india youth job say nsso last hour talk mamatavscbi neither modi mamata give rat ass countri ask right question',
#  'myfellowindian bengal guwahati assam bjp rule state',
#  'pm modi sat hous around hour hour ls hour rs last one year wherea spent around hour give speech gujarat assembl elect derekobrienmp tmc mp rs',
#  'akin attack democraci bjp goon think in sambit word may attack result frustrat onli vs',
#  'rahulliecaught expos pappu pleas bring fake news boot licker msm old yrs sir drgpradhan need ur help',
#  'help bankrupt friend get rich bjp govern deni air forc number jet sought seek polit benefit surgic strike ask how s joshlook cheat armi rm how s shame',
#  'gene nehru khandan great grand father nehru began crush rssorg generat line congi that is get crush rss grown steadili imagin generat obsess rss',
#  'vickypat rahul gandhi yes rememb often even one happi wing stallion familymr karadi bought son singl hand rahul rahul gandhi replac lost father husband',
#  'wait ani report visit bjp leader parshottam solanki hous give us complet stori',
#  'asharangappa found yell tv is way mother rais you disrespect us congress countri dare you answer question yes no',
#  'bill introduc us congress remov percountri green card limit via toibusi',
#  'abus power dem show complet noth get done congress get idiot dem offic',
#  'masterstrok hon ble pm shri modi',
#  'write rahul gandhi script',
#  'dog need help tell congress stop cruel taxpayerfund experi sign petit via chang',
#  'congress must take lead sinc presid confus differ weather climat',
#  'arrog everi peak declin side too modi forgotten this',
#  'bjpindia rahul gandhi pm modi bjp tht need think lie peddl next day chowkidaar gut hold pc debat rafal think need peddl lie pakdagayamodi darpokmodi chowkidarhichorhai',
#  'pm modi lay foundat esic hospit time india via timesofindia',
#  'icon thing happen congress ever',
#  'devendrafadnavi tri project shivsena desper allianc bjp upcom poll say congress lacharsena',
#  'woman take us shoulder carri outrag congress her felt powerless took power back rep like aoc ayannapressley ilhanmn everi amaz rep refus back us',
#  'tavleensingh ploy equat modi mani fail attempt mani joker one anoth rememb arvindkejriw',
#  'black flag wave modi guwahati pliabl media hush up cannot hush anger mass bewar',
#  'i ve figur out coward rahul gandhi attack pm modi',
#  'vinirish oldhandhyd rahul gandhi rahul uncultur uncouth stupid lie clown high insensit understand sensit soldier famili asshol mock anyth anybodi idiot',
#  'vote aap you',
#  'ka bjp functionari condemn brutal murder ramalingam tn polit leader got hole tight shut graveyard silenc justiceforramalingam',
#  'acypl mourn loss former congressman johndingel longestserv member congress us histori world war ii veteran skill legisl lifelong public servant legaci set exampl generat come',
#  'noth new modi s speech parliament old target rhetor opposit fall trap concentr real issu like unemploy agrarian crisi etc modimahamilawatattack',
#  'rahul gandhi rahul gandhi happi lie piddi rt check found bott rahul gandhi get well soon rahulkabaapchorhai',
#  'assam aasu pk mahantav join enemi hindus pkm succeed achiev anyth assam till india hindus thru modi amp bjp help implement sincer agreement pkmahantaassam arpitupadhayay debdip ayogesa meerathemistri rajkarsewak',
#  'corrupt modi visit pari cancel previous rafal deal behalf ambanih broker new deallapdog media still readi expos scam new rafal dealrath would tri cover whole issuethank thehindu pakdagayamodi',
#  'rahulliecaught rahul rahul gandhi conceal part parrikar signatur share view use hashtag tune live',
#  'happen now presid hous floor first time sinc elect congress tune in gt',
#  'karunagop moron believ nitingadkari s famili barb aim modi without realis rss pracharak left famili behind work bharat mata realli think gadkari run pracharak',
#  'that is british said issu general warrant polit oppon pleas stop lie oversight job congress govern depart target attack one individu famili corrupt filth dc near univers hate',
#  'rahulliecaught republ incindia echo system want divert attent vadra thehindu hindu print half document part plan ndtv indiatoday run stori continu rahul gandhichorhai rafalecongselfgo',
#  'defenc minist paper aya samn pakdagayamodi profit rafal scam bjp anil ambani modi amp dassault lost due rafal scam hal air forc tax payer incindia rahul gandhi pakdagayamodi',
#  'trinamool congress send notic republ kolkata showdown coverag boom',
#  'apart crass languag rahul rahul gandhi ignor bafoon except qualiti lie confid',
#  'bhupendrachaub modi bhupendra get life join bjp amd fight elect stop limitless sycoph pukeworthi sujataanandan minicnair rupagulab',
#  'shefvaidya rahul gandhi share video iaf friend spread everywher look like rahul rahul gandhi would lose lakh vote personnel arm forc famili within week forev',
#  'congress bought bullet proof jacket armi year upa rule endang live armymen threaten secur countri half year modi govt bullet proof jacket procur modiunstopp',
#  'bullet train get clearanc pass flamingo sanctuari nation park amp un gave modi highest environ award joke',
#  'mani watch franc itali fight diplomat war go deep find arm dealer amp indian connect sinc cannot succeed modi macron target',
#  'yrdeshmukh entir opposit support anarchist mamta r make ls elect presedenti us type n issu modi modi help modi across india n swing n consolid vote favour modi general n particular undecid voter mg scari',
#  'tnvellalarsagainstbjp modi down',
#  'meet burari assembl block presid main congress delhi mahilla congress offic bearer well ex mc candid discuss way strengthen parti assembl meet held burari block congress committe offic',
#  'congress renam gurgaon jamaica land jamai ka vadra vadrafil vadrafaces',
#  'open amp shut case report publish the hindu make crystal clear pm direct involv negoti bypass process give benefit anil ambani rahul rahul gandhi alleg pakdagayamodi rafalescam',
# ...
#  'jothim heard tamil peopl start tnwelcomesmodi chor like congress dmk alli start gobackmodi fortun gobackmodi use croni capitalist relianc jio guy eat anyth',
#  'tnwelcomesmodi dmkfail trade indian farmer onlin agri platform enam peg rs crore',
#  'udaan give wing girl student address lower enrol girl engin collegesiit technolog institut tnwelcomesmodi dmkfail',
#  'tnwelcomesmodi dmkfail road safeti modi govt spend rs crore fix accidentpron spot',
#  'rkhuria upa yoy nda yoy market continu growth trajectori may sensex would cross sensex move differ govt sensechang term start date start term year year full term gobackmodi',
#  'year ago st edit global lifi congress see glc lifi th th june les salon hoch i begin',
#  'singl tn fisherman lost life srilankan navi present bjp rule dravidian parti close hole navdwaram ppl state thank modiji this tnwelcomesmodi modi bjptamilnadu',
#  'jothim peopl fight neighbor state water issu end blame modi',
#  'reflect nda govern complet four year power arun jaitley nda govern led prime minist modi complet four year offic today tnwelcomesmodi dmkfail',
#  'my name raga teaser out dont want call biopic director',
#  'aiboc leader com sunil kumar com debasi ghosh com soumya dutta com ravind gupta com tapa ghosh other meet sh rahul gandhi presid aicc today submit memorandum discuss issu merger wage settlement nps denationalis public sect',
#  'tnwelcomesmodi dmkfail congress gave away bad loan modi govern ibc law help bring back',
#  'dear thehindu effort save nramind deserv accolad avid reader hindu sinc crop imag disgust turn propaganda paper congress parti',
#  'ranjinitam utterlybutt inkedmonk sureshhawar rahul gandhi meemilind udaynirgudkar shelarashish shelarkiran gobackmodi gobackculpritmodi utterlybutt someon pleas educ modi insult role pm',
#  'rafal scam simpl rahul rahul gandhi tell differ rafal price everyday liarrahul',
#  'strong bond assam bjp seen ralli amingaon today centr assam govern take numer step progress state recent budget assam govern transform impact',
#  'modi govern determin make healthcar access amp afford year tnwelcomesmodi dmkfail',
#  'kerala amp tn modi feel music ap southern belt last bastion fascism gobackmodi',
#  'take import decis need permiss mamta sarathbhawar mayavathi mulyam stalin chandra babu naidu need peopl permiss tnwelcomesmodi',
#  'commit provid shelter minor neighbour countri leav india partit assur assam northeast harm anyway due nation commit pm shri narendramodi northeastformodi',
#  'joker vaiko tirupur idea what s come tomorrow gang tharamaana sambavam wait him tnwelcomesmodi',
#  'let welcom pm india tnwelcomesmodi',
#  'friend chennai age see modiji visit welcom step understand focus develop tamilnadu definit narrat trend seem chang tamilnadu still long way go wish bjp best tnwelcomesmodi',
#  'modi go deal dumil tnwelcomesmodi dmkfail',
#  'tripura state depriv develop pretext landlock region made gateway south east asia pm modi northeastformodi',
#  'tnwelcomesmodi dmk brought scam bjp brought scheme dmkfail',
#  'first time state paddi procur msp besid recommend th pay commiss implement pm modi tripura northeastformodi',
#  'inspect vivekanda colleg ground kanniyakumari pm sh modi ji go particip govt function bjptamilnadu kanniyakumari district bjp meet review stage park facil site ctravibjp piyushgoy myra pmoindia',
#  'rahul rahul gandhi stay night wonder new lie peddl tomorrow morn leav goal happi weekend peopl liarrahul',
#  'gobackmodi hashtag handiwork dmk amp follow alway blame centr everi sin amp want keep north south divid intact polit gain garcic drama dmk amp entir tamilnadu tnwelcomesmodi maduraithanksmodi',
#  'prove sir rahul dravid greater mumbai lad sachin tendulkar know will',
#  'modi govern control inflat tnwelcomesmodi',
#  'new twitter id pleas copi past content when came twitter without know anyth tweet go back modi',
#  'never thought day would come bhakt abus ram hindu defend modi ironi okby backtomybreak',
#  'modi insurg reviv assam know congressupa number milit outfit suspend oper promin exampl dima halam daogah amp ranjan daimari faction ndfb alon milit surrend',
#  'leadership pm modi ji govt india took histor decis renam agartala airport maharaja bir bikram airport befit tribut architect modern tripura honbl pm unveil statu agartala airport today northeastformodi',
#  'ujala scheme led light subsid rate core led bulb distribut far unit electr save tnwelcomesmodi',
#  'develop nation drive world s gradual shift toward renew energi india becom one leader pack tnwelcomesmodi dmkfail',
#  'tnwelcomesmodi forev india best pm',
#  'pm shri modi lay foundat stone inaugur develop project itanagar arunach pradesh watch northeastformodi',
#  'pm modi dedic various develop project nation guwahati assam northeastformodi',
#  'tnwelcomesmodi modi great leader',
#  'modi govt jallikattu secur tn fishermen bring defenc corridor state aayushman bharat scheme aiim tnwelcomesmodi dmkfail',
#  'periyar would welcom pm mrmodi ji gobackmodi',
#  'urgent time wast help defendmarinemamm tell member congress defend whale dolphin marin mammal reject legisl would weaken marin mammal protect act',
#  'tnwelcomesmodi dmkfail tn benefit pm modi pm done much state',
#  'make modi famousw world level trend no darpokmodi gobackmodi gobacksadistmodi',
#  'tnwelcomesmodi genius genuin honest person vote bjp',
#  'modi tneven hilli area benefit thru swachabharat missionthes toilet peopl yelagiri hill construct scheme pictur two differ hous yelagiri hill shot june tnwelcomesmodi dmkfail',
#  'north east kick modi modidestroysnortheast trend tamil nadu kick modi gobackmodi waarre wah',
#  'credit develop first high speed train t also goe tamil nadu time come t provid high speed connect across countri pm tnwelcomesmodi dmkfail',
#  'new branch aiim creat balanc doctorpati ratio govern work reduc shortag doctor improv qualiti healthcar tnwelcomesmodi dmkfail',
#  'year modi ji india risen world s th largest economi th place next year one power nation world tnwelcomesmodi dmkfail',
#  'pm modi ji done tn over l unjwala gas connect cr chennai metro rail cr worth crop insur l toilet built mudra loan lcr distribut tn prestigi aiim madurai tnwelcomesmodi dmkfail',
#  'prime moron gut constitut jpc claim inch chest fill air alreadi blown rss bear blunt face elect histori seen autocrat take everyth grant pakdagayamodi',
#  'tnwelcomesmodi even rahul gandhi surpris see warm welcom modi bcoz even get type respect home',
#  'last year speed highway construct doubl speed project pend year increas tnwelcomesmodi dmkfail bharatbacksmodi',
#  'gobackmodi black balloon effigi burnt guwahati protest bjp escal',
#  'ani quot meghalaya cm conrad sangma nation peopl parti also decid bill citizenshipamendmentbil pass rajya sabha parti break tie nda decis taken today general bodi meet',
#  'who gift un perman seat china who drag kashmir conflict un who impos emerg desh mai pehla plain hijack indira rahul gandhi ko jail se chhudan k liya hua tha baad mai usi terrorist ko mai mla bhi banaya tha',
#  'dear bhaktswhi mrmodi visit gaja cyclon victimsbut day visit nd timegobackmodi',
#  'trend tnwelcomesmodi th posit tweet amp gobackmodi st posit tweet partial twitter twitterinsultsindia cheatertwitt ianuragthakur tajinderbagga amitmalviya',
#  'result go back modi tnwelcomesmodi dmkfail',
#  'ipr awar amongst student youth author artist bud inventor profession inspir creat innov protect creation invent tnwelcomesmodi dmkfail',
#  'trendsntr geevanjivarun gobackmodi wrong time modi visit south india b trend world pick wrong date sir',
#  'time kick dmk tn dmkfail welcom bjp tnwelcomesmodi',
#  'china recogn area india call arunach pradesh firm oppos indian pm modi recent visit disput area china stanc issu chinaindia border consist clear chines foreign ministri spokesperson said saturday',
#  'gobackmodi yes year gujrat cm and half year pm modi still honest modi ji pleas make money like vadrakalmadi rahul ghandi lalu prasad sharda scam tn welcom tnwelcomesmodi seriousfunnyguy shobhabjp rishibagre',
#  'bjpindia hey bjpindia expos nation know insult low life tweet fekus guilt guy caught act iniqu bjp give certif lie talk honesti like demon preach peac',
#  'gobackmodi get gobackmodi vote bjp gobackmodi gobackmodi shameless gobackmodi gobackmodi gobackmodi',
#  'nehru indira rajeev sonia rahul robert crimin jmantprbahrhaisoniakalalhai chorikekhelmejijasalabailp',
#  'niryat bandhu scheme reach new amp potenti export mentor orient programm counsel session individu facilit get intern trade boost export india tnwelcomesmodi dmkfail tnbjp',
#  'honest confess courag decis tell truth pmoindia made true statement long time year modi govt destroy constitut institut',
#  'inspect discuss venu honour pm modi address gather lakh strong bjp worker western belt get readi getmodifi pmmodi pmintamilnadu tirupurwelcomesmodi bjptamilnadu drtamilisaibjp',
#  'there two indian prime minist experienc poverti lal bahadur shastri amp modi like bjp pride india amp indian ace investor rakesh jhunjhunwala modi back prime minist elect',
#  'bainjal mahapatpravat modi bjp memberssupport quit twitter start use namo app futur communic twitterkovanakam',
#  'pm modi declar household electrif arunach pradesh',
#  'pleas plan visit tn general elect dmk jihadi go bankrupt spend trend gbackmd tnwelcomesmodi dmkfail',
#  'ne bpo promot scheme modi bring happi youth ne state bring electr unelectrifi villag ensur make northeast bpo capitalmodi govern done except well better ne ppl northeastformodi',
#  'realiz modi pm',
#  'indian tamil fishermen shot dead srilankan navi year upa singl fisherman casualti last year modi sarkaar tnwelcomesmodi dmkfail',
#  'rahul gandhi win elect armi chief we need budget xyz crore rupe buy new assault rifl amp ammunit armi rahul whi wast xyz crore rupe weapon ammunit give xyz crore rupe armymen s famili die battl',
#  'gobackmodi peopl strong behind bjp',
#  'tejashwi mark faster bjp jdu hope set agenda rather play catchup respond oppon',
#  'year independ year conflict prime minist pm give conclus cauveri issu tnwelcomesmodi dmkfail',
#  'modi gobackmodi andhra peopl cannot even arrang crowd meet tomorrow telugu one gng listen tomorrow move back',
#  'gst variti indirect tax erad tax gst result increas eas busi tnwelcomesmodi dmkfail',
#  'gobackmodi gobackmodi atroc modi regim thoothukudi massacr neet murder obstruct keezhadi excav hindi imposit engin student unemploy ochki cyclon kuangini fire accid fisherman issu gaja cyclon farmer protest',
#  'zayn elleindia fashion editor rahul vijay last year',
#  'bjp see tamil ident part indian ident tamil way second hindi sanskrit tamil equal sacr muralidhar rao',
#  'tnwelcomesmodiindian railway creat record lhb coach made last year year sinc introduct tnwelcomesmodi dmkfail',
#  'develop prime minist modi assam biggest state region bjp got lok sabha seat today want give one target seat northeast tnwelcomesmodi dmkfail',
#  'two year gop congress refus hold presid administr account congress will seem white hous angri jame madison set system check balanc us constitut',
#  'bharatbacksmodi requir evid peopl consid chor amp chor accus chor chor chorfor peopl chowkidar sher hailisten himhi anger villain',
#  'modi hate cybercooli mock action protect women honor pathet modi came power children die age due open defec modi save build toilet big shame peopl like mock this tnwelcomesmodi',
#  'bjp regim countri give problem indiansbcoz believ indian pm n govern alway give problem indian gobackmodi',
#  'in hate modi opposit begun hate nation pm modi fierc attack congress lok sabha via namo app',
#  'transform india world bank report demonet reduc circul fake currenc gdp increas higher rate tnwelcomesmodi dmkfail',
#  'bare week modi start campaign wb tmc mla satyajit biswa recent marri shot dead phulbari',
#  'paytm mall new bike offer buy sport bike amp get benefit worth buy offer paytm livbou massgodntrbdayinday atletirealmadrid tnwelcomesmodi iwobi morata huddersfield balesfilmchalleng',
#  'hearti welcom tamil nadu shri modi ji tnwelcomesmodi',
#  'tnwelcomesmodi uncouth boorish dmk support hide rock ramlingam death attend train session slither bottom rock trend gobackmodi video one train session',
#  'glimps prime minist modi jis public meet foundat lay ceremoni aiim madurai tamil nadu thank peopl madurai made today program huge success tnwelcomesmodi',
#  'citi des moin mattwhitak mem invest fund hud congress appropri cc repmaxinewat adamschiff repcum link page hud back loan',
#  'pm modi serv akshaya patra billionth meal underprivileg kid vrindavan monday let libbi amp commi file petit close akshay patra now',
#  'none harshad chopda rule itv brilliant perform aditya hooda shahrukh creat rahul harshad chopda creat aditya hooda love moon back',
#  'pokershash would shot good member claim bjp kill massacr bjp member',
#  'pleas prime minist take rahul gandhi s offer televis debat',
#  'share max might listen various version azadi songrap made congressbjp suit agenda origin version talk azadi wrongdo societi spend min understand need azadi',
#  'thank honb pmoindia modi ji tn visit dedic aiim hospit madurai amp public meet great motiv all work hard see pmnamoagain namoapp amitshahoffic bjpindia maduraithanksmodi tnwelcomesmodi',
#  'tnwelcomesmodi thank pm modi gift much await qualiti health care madurai indian sure like infrastructur india seen come you even come record time pmoindia bjpindia burnolcongress',
#  'bengal robert vadra bjp get time wrong may even boomerang column httweet',
#  'serialliarrahul label rahul serial liarthi dishonest chest total irrat ampunreasonablerahul anti indian he betray amp treacher so simpli design rahul liari incorrectrahul rahul gandhi break indiah link tukd tukd gang',
#  'rahul rahul gandhi realis want live india must live like hindu myogiadityanath aapkiadalat watch yogiinaapkiadalat tonight indiatvnew cmofficeup',
#  'tallest leader india make visit tamil nadu proud pm modi maduraithanksmodi tnwelcomesmodi',
#  'credit develop first high speed train t also goe tamil nadu time come t provid high speed connect across countri pm modi tnwelcomesmodi',
#  'met note bollywood directorproducerwrit sh anil sharma ji offic direct famous movi like gadar ek prem katha apn the hero veer mani movi big fan support prime minist shnarendramodi ji tnwelcomesmodi namoagain',
#  'northeast upa tenur arunach pradesh railway ke liy kalapani hai northeast nda tenur india s longest railcumroad bogibeelbridg via pm narendramodi s act east polici northeastformodi bharatbacksmodi saturdaymotiv',
#  'dhamkana chood hm mrrajnathsingh modi chor hai fail haiaap bakwaa kar rahe haidont threaten peopl india mr home minist modi fail liar pm oknot',
#  'tirupur eager wait receiv honour pm modi pmoindia tamilnadu welcom pm amitshah bjptamilnadu bjpindia tnwelcomesmodi dmkfail',
#  'shodhganga repositori develop contain electron copi mphilphd thesi make access institut tnwelcomesmodi dmkfail',
#  'modi ji discov great select best toy kid start kid imagin engin remot control play vehicl parikshapecharcha pakdagayamodi modidestroysnortheast divyaspandana hasibaamin',
#  'rahul rahul gandhi fake rts follow vote twitter anyon know organ help this',
#  'tnwelcomesmodi showcas love respect wherea gobackmodi showcas hatr alway love respect win',
#  'realiti is modi attack owner media hous guwahati spread lie amp fake propaganda use media captur power dispur',
#  'petti pueril piti presid congress parti',
#  'tnwelcomesmodi reserv',
#  'modi ji shown black flag assam gobackmodi citizenshipamendmentbil',
#  'bless disguis emot charg state like tn is also emot turn upsid within day two need watersh dramat momentev what is event could be tnwelcomesmodi',
#  'tnwelcomesmodi northeastformodi bharatbacksmodi gobackmodi reason vote modi vote modi thank namo',
#  'silverfox never forget antisemitesthey sinc arriv muhammad noth chang messag clear speak hate direct hide it intoler amp bigotri amp racism a sieg within congress wakeup covfef',
#  'aiimsmadurai tnwelcomesmodi maduraithanksmodi vaiko one among got crush',
#  ...]

# %% [markdown]
# # Inserting Processed Tweets

# %%
df.insert(4,"processed_tweet",preprocessed,True)
df.head()
# Out:
#          last_updated      tweet_id          created_at  \
# 0 2019-02-08 17:29:00  1.090000e+18 2019-02-08 17:28:00
# 1 2019-02-08 17:29:00  1.090000e+18 2019-02-07 05:10:00
# 2 2019-02-08 17:30:00  1.090000e+18 2019-02-08 10:18:00
# 3 2019-02-08 17:30:00  1.090000e+18 2019-02-08 17:29:00
# 4 2019-02-08 17:30:00  1.090000e+18 2019-02-08 14:19:00
#
#                                            full_text  \
# 0  @DasComrade Sir any comment on modi's grand en...
# 1  Congress made Vemula national talking point ev...
# 2  BJP has been winning battles over the past mon...
# 3  @inclusivemind2 @Ark82876233 @BJP4India @Rahul...
# 4  Senior Congress leader @ManishTewari : There w...
#
#                                      processed_tweet  quote_count  \
# 0             dascomrad sir comment modi grand entri          0.0
# 1  congress made vemula nation talk point even th...         47.0
# 2  bjp win battl past month bengal pm modi arriv ...          1.0
# 3  inclusivemind ark bjpindia rahul gandhi bjp th...          0.0
# 4  senior congress leader manishtewari jpc defini...          0.0
#
#    reply_count  retweet_count  favorite_count hashtags  \
# 0          0.0            1.0               1
# 1         72.0         2353.0            2353
# 2         12.0          513.0             513
# 3          0.0            2.0               2
# 4          1.0          159.0             159
#
#                           user_mentions_screen_name       City          State  \
# 0                                        DasComrade   Guwahati          Assam
# 1                                                       Mumbai    Maharashtra
# 2                                                      Kolkata    West Bengal
# 3  inclusivemind2,Ark82876233,BJP4India,RahulGandhi    Aligarh  Uttar Pradesh
# 4                                      ManishTewari  New Delhi          Delhi
#
#   Country
# 0   India
# 1   India
# 2   India
# 3   India
# 4   India

# %% [markdown]
# # Finding most tagged twitter handles

# %%
df["user_mentions_screen_name"].value_counts()[:9]
# Out:
#                   25080
# narendramodi       1377
# RahulGandhi         693
# INCIndia            399
# BJP4India           143
# ANI                 110
# priyankagandhi       99
# AmitShah             98
# ArvindKejriwal       97
# Name: user_mentions_screen_name, dtype: int64

# %% [markdown]
# # Processing Sentiment Scores

# %%
sentiment = {"Positive":[], "Negative" :[], "Neutral":[], "Compound":[]}
for i in df["processed_tweet"]:
    sentiment["Positive"].append(sid.polarity_scores(i)['pos'])
    sentiment["Negative"].append(sid.polarity_scores(i)['neg'])
    sentiment["Neutral"].append(sid.polarity_scores(i)['neu'])
    sentiment["Compound"].append(sid.polarity_scores(i)['compound'])

# %%
df.insert(9,"Neutral",sentiment['Neutral'],True)
df.insert(10,"Positive",sentiment['Positive'],True)
df.insert(11,"Negative",sentiment['Negative'],True)
df.insert(12,"Compound",sentiment['Compound'],True)

# %%
df.head()
# Out:
#          last_updated      tweet_id          created_at  \
# 0 2019-02-08 17:29:00  1.090000e+18 2019-02-08 17:28:00
# 1 2019-02-08 17:29:00  1.090000e+18 2019-02-07 05:10:00
# 2 2019-02-08 17:30:00  1.090000e+18 2019-02-08 10:18:00
# 3 2019-02-08 17:30:00  1.090000e+18 2019-02-08 17:29:00
# 4 2019-02-08 17:30:00  1.090000e+18 2019-02-08 14:19:00
#
#                                            full_text  \
# 0  @DasComrade Sir any comment on modi's grand en...
# 1  Congress made Vemula national talking point ev...
# 2  BJP has been winning battles over the past mon...
# 3  @inclusivemind2 @Ark82876233 @BJP4India @Rahul...
# 4  Senior Congress leader @ManishTewari : There w...
#
#                                      processed_tweet  quote_count  \
# 0             dascomrad sir comment modi grand entri          0.0
# 1  congress made vemula nation talk point even th...         47.0
# 2  bjp win battl past month bengal pm modi arriv ...          1.0
# 3  inclusivemind ark bjpindia rahul gandhi bjp th...          0.0
# 4  senior congress leader manishtewari jpc defini...          0.0
#
#    reply_count  retweet_count  favorite_count  Neutral  Positive  Negative  \
# 0          0.0            1.0               1    0.625     0.375     0.000
# 1         72.0         2353.0            2353    0.868     0.000     0.132
# 2         12.0          513.0             513    0.582     0.276     0.142
# 3          0.0            2.0               2    0.884     0.116     0.000
# 4          1.0          159.0             159    1.000     0.000     0.000
#
#    Compound hashtags                         user_mentions_screen_name  \
# 0    0.4588                                                 DasComrade
# 1   -0.5719
# 2    0.5719
# 3    0.4404           inclusivemind2,Ark82876233,BJP4India,RahulGandhi
# 4    0.0000                                               ManishTewari
#
#         City          State Country
# 0   Guwahati          Assam   India
# 1     Mumbai    Maharashtra   India
# 2    Kolkata    West Bengal   India
# 3    Aligarh  Uttar Pradesh   India
# 4  New Delhi          Delhi   India

# %% [markdown]
# # Summarising RT's, Quotes and Replies

# %%
df.loc[:,"quote_count":"retweet_count"].describe()
# Out:
#         quote_count   reply_count  retweet_count
# count  39874.000000  39874.000000   39874.000000
# mean      10.774038     32.574284     446.036615
# std      114.089735    309.171354    2708.395701
# min        0.000000      0.000000       0.000000
# 25%        0.000000      0.000000       2.000000
# 50%        0.000000      1.000000      18.000000
# 75%        2.000000      7.000000     135.000000
# max    13544.000000  19447.000000  206958.000000

# %% [markdown]
# # Analysing Tweet Importance

# %%
imp = []
for i in range(0,39874):
    if df["retweet_count"][i]>=50 or sum([df["retweet_count"][i],df["quote_count"][i],df["reply_count"][i]])>=50:
        imp.append(1)
    else:
        imp.append(0)

# %%
df.insert(8,"Importance",imp,True)
df.head()
# Out:
#          last_updated      tweet_id          created_at  \
# 0 2019-02-08 17:29:00  1.090000e+18 2019-02-08 17:28:00
# 1 2019-02-08 17:29:00  1.090000e+18 2019-02-07 05:10:00
# 2 2019-02-08 17:30:00  1.090000e+18 2019-02-08 10:18:00
# 3 2019-02-08 17:30:00  1.090000e+18 2019-02-08 17:29:00
# 4 2019-02-08 17:30:00  1.090000e+18 2019-02-08 14:19:00
#
#                                            full_text  \
# 0  @DasComrade Sir any comment on modi's grand en...
# 1  Congress made Vemula national talking point ev...
# 2  BJP has been winning battles over the past mon...
# 3  @inclusivemind2 @Ark82876233 @BJP4India @Rahul...
# 4  Senior Congress leader @ManishTewari : There w...
#
#                                      processed_tweet  quote_count  \
# 0             dascomrad sir comment modi grand entri          0.0
# 1  congress made vemula nation talk point even th...         47.0
# 2  bjp win battl past month bengal pm modi arriv ...          1.0
# 3  inclusivemind ark bjpindia rahul gandhi bjp th...          0.0
# 4  senior congress leader manishtewari jpc defini...          0.0
#
#    reply_count  retweet_count  Importance  favorite_count  Neutral  Positive  \
# 0          0.0            1.0           0               1    0.625     0.375
# 1         72.0         2353.0           1            2353    0.868     0.000
# 2         12.0          513.0           1             513    0.582     0.276
# 3          0.0            2.0           0               2    0.884     0.116
# 4          1.0          159.0           1             159    1.000     0.000
#
#    Negative  Compound hashtags  \
# 0     0.000    0.4588
# 1     0.132   -0.5719
# 2     0.142    0.5719
# 3     0.000    0.4404
# 4     0.000    0.0000
#
#                           user_mentions_screen_name       City          State  \
# 0                                        DasComrade   Guwahati          Assam
# 1                                                       Mumbai    Maharashtra
# 2                                                      Kolkata    West Bengal
# 3  inclusivemind2,Ark82876233,BJP4India,RahulGandhi    Aligarh  Uttar Pradesh
# 4                                      ManishTewari  New Delhi          Delhi
#
#   Country
# 0   India
# 1   India
# 2   India
# 3   India
# 4   India

# %%
df["Importance"].value_counts()
# Out:
# 0    24544
# 1    15330
# Name: Importance, dtype: int64

# %% [markdown]
# # Correlating Tweet Attributes

# %%
dfcorr = df.corr(method="pearson")

# %%
dfcorr
# Out:
#                 tweet_id  quote_count  reply_count  retweet_count  Importance  \
# tweet_id        1.000000    -0.041689    -0.020012      -0.022955   -0.005577
# quote_count    -0.041689     1.000000     0.800002       0.622179    0.116798
# reply_count    -0.020012     0.800002     1.000000       0.719914    0.130431
# retweet_count  -0.022955     0.622179     0.719914       1.000000    0.204256
# Importance     -0.005577     0.116798     0.130431       0.204256    1.000000
# favorite_count -0.022955     0.622179     0.719914       1.000000    0.204256
# Neutral         0.005210    -0.014657    -0.015987      -0.019757   -0.014811
# Positive       -0.000297     0.003821     0.005671       0.022822    0.007710
# Negative       -0.006349     0.014949     0.014840       0.002982    0.011366
# Compound        0.002504    -0.010084    -0.009755       0.011925   -0.001475
#
#                 favorite_count   Neutral  Positive  Negative  Compound
# tweet_id             -0.022955  0.005210 -0.000297 -0.006349  0.002504
# quote_count           0.622179 -0.014657  0.003821  0.014949 -0.010084
# reply_count           0.719914 -0.015987  0.005671  0.014840 -0.009755
# retweet_count         1.000000 -0.019757  0.022822  0.002982  0.011925
# Importance            0.204256 -0.014811  0.007710  0.011366 -0.001475
# favorite_count        1.000000 -0.019757  0.022822  0.002982  0.011925
# Neutral              -0.019757  1.000000 -0.632498 -0.658254  0.062636
# Positive              0.022822 -0.632498  1.000000 -0.166741  0.671093
# Negative              0.002982 -0.658254 -0.166741  1.000000 -0.731972
# Compound              0.011925  0.062636  0.671093 -0.731972  1.000000

# %% [markdown]
# # Setting up Scoring Function

# %%
m11 = dfcorr["Compound"]["quote_count"]
m22 = dfcorr["Compound"]["reply_count"]
m33 = dfcorr["Compound"]["retweet_count"]
m44 = dfcorr["Compound"]["favorite_count"]
m55 = dfcorr["Compound"]["Importance"]

#Positive or compound?

m1 = dfcorr["Positive"]["quote_count"]
m2 = dfcorr["Positive"]["reply_count"]
m3 = dfcorr["Positive"]["retweet_count"]
m4 = dfcorr["Positive"]["favorite_count"]
m5 = dfcorr["Positive"]["Importance"]

# %%
score = lambda x1,x2,x3,x4,x5: m1*x1+m2*x2+m3*x3+m4*x4+x5
#score1 = lambda x1,x2,x3,x4,x5: m11*x1+m22*x2+m33*x3+m44*x4+x5

# %%
#Random test case
score(10,20,30,10,0)
# Out:
# 1.064519682388548

# %%
score(10,20,30,10,1)
# Out:
# 2.064519682388548

# %% [markdown]
# # Scoring Tweets

# %%
scores = []
for i in range(0,39874):
    qt = df["quote_count"][i]
    reply = df["reply_count"][i]
    rt = df["retweet_count"][i]
    fav = df["favorite_count"][i]
    imp = df["Importance"][i]
    scores.append(score(qt,reply,rt,fav,imp))

# %%
df["Score"] = scores

# %%
df.head()
# Out:
#          last_updated      tweet_id          created_at  \
# 0 2019-02-08 17:29:00  1.090000e+18 2019-02-08 17:28:00
# 1 2019-02-08 17:29:00  1.090000e+18 2019-02-07 05:10:00
# 2 2019-02-08 17:30:00  1.090000e+18 2019-02-08 10:18:00
# 3 2019-02-08 17:30:00  1.090000e+18 2019-02-08 17:29:00
# 4 2019-02-08 17:30:00  1.090000e+18 2019-02-08 14:19:00
#
#                                            full_text  \
# 0  @DasComrade Sir any comment on modi's grand en...
# 1  Congress made Vemula national talking point ev...
# 2  BJP has been winning battles over the past mon...
# 3  @inclusivemind2 @Ark82876233 @BJP4India @Rahul...
# 4  Senior Congress leader @ManishTewari : There w...
#
#                                      processed_tweet  quote_count  \
# 0             dascomrad sir comment modi grand entri          0.0
# 1  congress made vemula nation talk point even th...         47.0
# 2  bjp win battl past month bengal pm modi arriv ...          1.0
# 3  inclusivemind ark bjpindia rahul gandhi bjp th...          0.0
# 4  senior congress leader manishtewari jpc defini...          0.0
#
#    reply_count  retweet_count  Importance  favorite_count  Neutral  Positive  \
# 0          0.0            1.0           0               1    0.625     0.375
# 1         72.0         2353.0           1            2353    0.868     0.000
# 2         12.0          513.0           1             513    0.582     0.276
# 3          0.0            2.0           0               2    0.884     0.116
# 4          1.0          159.0           1             159    1.000     0.000
#
#    Negative  Compound hashtags  \
# 0     0.000    0.4588
# 1     0.132   -0.5719
# 2     0.142    0.5719
# 3     0.000    0.4404
# 4     0.000    0.0000
#
#                           user_mentions_screen_name       City          State  \
# 0                                        DasComrade   Guwahati          Assam
# 1                                                       Mumbai    Maharashtra
# 2                                                      Kolkata    West Bengal
# 3  inclusivemind2,Ark82876233,BJP4India,RahulGandhi    Aligarh  Uttar Pradesh
# 4                                      ManishTewari  New Delhi          Delhi
#
#   Country       Score
# 0   India    0.045645
# 1   India  108.990410
# 2   India   24.487725
# 3   India    0.091290
# 4   India    8.263217

# %% [markdown]
# # Classifying Tweets - Testing K-Means

# %%
'''X = vectorizer.fit_transform(df["processed_tweet"])
k =3
model = KMeans(n_clusters=2, init='k-means++', max_iter=100)
model.fit(X)'''
# Out:
# 'X = vectorizer.fit_transform(df["processed_tweet"])\nk =3\nmodel = KMeans(n_clusters=2, init=\'k-means++\', max_iter=100)\nmodel.fit(X)'

# %%
'''order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(2):
    print("Cluster %d:" % i),
    for ind in order_centroids[i, :10]:
        print(' %s' % terms[ind]),
    print'''
# Out:
# 'order_centroids = model.cluster_centers_.argsort()[:, ::-1]\nterms = vectorizer.get_feature_names()\nfor i in range(2):\n    print("Cluster %d:" % i),\n    for ind in order_centroids[i, :10]:\n        print(\' %s\' % terms[ind]),\n    print'

# %%
#Y = vectorizer.transform(['''A multitude of supporters from across the length and breath of Bihar came out to listen to Congress President Shri @RahulGandhi today. #RahulGandhiInBihar https://t.co/f0O9RfxAeM'''])
#prediction = model.predict(Y)
#print(prediction)'''

# %% [markdown]
# # Testing Cosine Similarity

# %%
'''compare = ["bjp modi chowkidar rss",
          "congress rahul gandhi sonia pappu"]
party1 = []
for tweet in df["processed_tweet"]:
    sim = []
    sim.append([cosine_sim(compare[0],tweet),"BJP"])
    sim.append([cosine_sim(compare[1],tweet),"Congress"])
    sim.sort(key = lambda x: x[0],reverse = True)
    max_sim = sim[0][0]
    max_party = sim[0][1]
    if max_sim>0.2:
        party1.append(max_party)
    else:
        party1.append("Other")'''
# Out:
# 'compare = ["bjp modi chowkidar rss",\n          "congress rahul gandhi sonia pappu"]\nparty1 = []\nfor tweet in df["processed_tweet"]:\n    sim = []\n    sim.append([cosine_sim(compare[0],tweet),"BJP"])\n    sim.append([cosine_sim(compare[1],tweet),"Congress"])\n    sim.sort(key = lambda x: x[0],reverse = True)\n    max_sim = sim[0][0]\n    max_party = sim[0][1]\n    if max_sim>0.2:\n        party1.append(max_party)\n    else:\n        party1.append("Other")'

# %% [markdown]
# # Testing Frequency Classification

# %%
compare = ["vijay rajnath ravishankar  yudhvirsethi patra narendra modi vijayvargiyah sadhvi bjp arun manoj reddy sushma rsprasad taneja maneka udhavthackeray gautam gambhir piyush goyal nitin gadkari gadkariji rss singh vasundhraraje bjpbengal smriti kailash gautamgambhir swamy udhav sushmaswaraj sadhvi pragya vasundhra sambitpatra shivraj arunjaitley manohar parikar subramanianswamy naredra modi manojtiwari amit modiji yogi adityanath sushma swaraj nitin vivekreddy shivrajsinghchouhan vijayrupani amit shah narendramodi pragya arun jaitley thackeray sunny deol bharatiya janata party kailashvijayvargiyah adityanath yogi jaitley piyush gadkari sambit smritiirani rajnathsingh irani swaraj gautam parikar nirmala bhartiya janta party ram nirmala sitaraman modi shivrajsingh nititngadkari manohar rammadhav smriti irani yedyurappa madhav gambhir narendra rajnath singh subrmanian goyal chouhan amitshah sitaraman manoharparikar ravishankar prasad rupani rao shah ravishankarprasad narsimha vivek vijay rupani prasad bhartiya janata party giriraj chowkidar",
          "congress rahul gandhi sonia pappu manish tiwari mani shankar aiyar amrinder singh navjot sidhu pilot sachin jyotiraditya scindia ashok gehlot ajay makhan makhen chidambaram raj babbar sheila dikshit kamal nath digvijay singh sanjay kaul ashok chavan prithviraj randeep surjaewala hooda deepender kapil sibal manmohan ahmed patil natwar gaurav vallabh pawan khera taneja reddy george antony venugopal rao raman gogoi lalu prasad yadav akhilesh ravat urmila milind deora siddaramiah shivkumar dks sandeep ashok tanwar prakash jha"]

documents = df["processed_tweet"]
party = []
for i in documents:
    l = len(i.split())
    freq_bjp = 0
    freq_cong = 0
    for j in compare[0].split():
        freq_bjp+=i.count(j.strip())
    for j in compare[1].split():
        freq_cong+=i.count(j.strip())
    #print(freq_cong, freq_bjp)
    if freq_bjp>freq_cong:
        party.append("BJP")
    elif freq_cong>freq_bjp:
        party.append("Congress")
    else:
        party.append("Other")

# %% [markdown]
# # Checking Party Counts

# %%
party.count("Other")
# Out:
# 4307

# %%
party.count("BJP")
# Out:
# 20884

# %%
party.count("Congress")
# Out:
# 14683

# %%
plt.rcParams["figure.figsize"] = [6,6]
labels = ["BJP","Congress","Other"]
count = [party.count("BJP"),party.count("Congress"),party.count("Other")]
explode = (0.05,0.05,0.05)
patches, texts,autotexts = plt.pie(count,labels=labels, explode = explode,colors = ["orange","lightgreen","lightblue"], startangle=90, autopct='%1.1f%%',shadow = False, pctdistance=0.85)
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')  
plt.tight_layout()
plt.show()

# %% [markdown]
# # Inserting Party Attribute

# %%
df.insert(5,"Party",party)

# %%
df.head()
# Out:
#          last_updated      tweet_id          created_at  \
# 0 2019-02-08 17:29:00  1.090000e+18 2019-02-08 17:28:00
# 1 2019-02-08 17:29:00  1.090000e+18 2019-02-07 05:10:00
# 2 2019-02-08 17:30:00  1.090000e+18 2019-02-08 10:18:00
# 3 2019-02-08 17:30:00  1.090000e+18 2019-02-08 17:29:00
# 4 2019-02-08 17:30:00  1.090000e+18 2019-02-08 14:19:00
#
#                                            full_text  \
# 0  @DasComrade Sir any comment on modi's grand en...
# 1  Congress made Vemula national talking point ev...
# 2  BJP has been winning battles over the past mon...
# 3  @inclusivemind2 @Ark82876233 @BJP4India @Rahul...
# 4  Senior Congress leader @ManishTewari : There w...
#
#                                      processed_tweet     Party  quote_count  \
# 0             dascomrad sir comment modi grand entri       BJP          0.0
# 1  congress made vemula nation talk point even th...       BJP         47.0
# 2  bjp win battl past month bengal pm modi arriv ...       BJP          1.0
# 3  inclusivemind ark bjpindia rahul gandhi bjp th...     Other          0.0
# 4  senior congress leader manishtewari jpc defini...  Congress          0.0
#
#    reply_count  retweet_count  Importance  ...  Neutral  Positive  Negative  \
# 0          0.0            1.0           0  ...    0.625     0.375     0.000
# 1         72.0         2353.0           1  ...    0.868     0.000     0.132
# 2         12.0          513.0           1  ...    0.582     0.276     0.142
# 3          0.0            2.0           0  ...    0.884     0.116     0.000
# 4          1.0          159.0           1  ...    1.000     0.000     0.000
#
#    Compound  hashtags                         user_mentions_screen_name  \
# 0    0.4588                                                  DasComrade
# 1   -0.5719
# 2    0.5719
# 3    0.4404            inclusivemind2,Ark82876233,BJP4India,RahulGandhi
# 4    0.0000                                                ManishTewari
#
#         City          State Country       Score
# 0   Guwahati          Assam   India    0.045645
# 1     Mumbai    Maharashtra   India  108.990410
# 2    Kolkata    West Bengal   India   24.487725
# 3    Aligarh  Uttar Pradesh   India    0.091290
# 4  New Delhi          Delhi   India    8.263217
#
# [5 rows x 21 columns]

# %%
df["Party"].value_counts()
# Out:
# BJP         20884
# Congress    14683
# Other        4307
# Name: Party, dtype: int64

# %% [markdown]
# # Obtaining Time Intervals

# %%
time_sec = list(set(df["last_updated"]))
time_sec.sort()

# %%
time_day = set()
time_month = set()
for i in time_sec:
    time_day.add(i.date())
    time_month.add(i.month)
time_day = list(time_day)
time_day.sort()
time_month = list(time_month)
time_month.sort()

# %%
time_week = set()
time_fortnight = set()
result=time_day[0]
while result<= time_day[-1]:
    time_week.add(result)
    result+=timedelta(days=7)
time_week = list(time_week)
time_week.sort()

# %%
result = time_day[0]
while result<= time_day[-1]:
    time_fortnight.add(result)
    result+=timedelta(days=15)
time_fortnight = list(time_fortnight)
time_fortnight.sort()

# %%
all_hour = []
result = time_sec[0]
while result<= time_sec[-1]:
    all_hour.append((result.date(),result.hour))
    result+=timedelta(hours=1)

# %%
all_min = []
result = time_sec[0]
while result<= time_sec[-1]:
    all_min.append((result.date(),result.hour,result.minute))
    result+=timedelta(minutes=1)

# %% [markdown]
# # Popularity per Tweet

# %%
score_sec = {}
for t in time_sec:
    score_sec[t] = {"BJP":0,"Congress":0,"Other":0}
for i in range(0,39874):
    t = df["last_updated"][i]
    score_sec[t][df["Party"][i]]+=df["Score"][i]
#print(score_min)

# %%
sec_total_bjp, sec_total_cong, sec_total_other = [],[],[]
for i in score_sec:
    try:
        sec_total_bjp.append(score_sec[i]["BJP"]+sec_total_bjp[-1])
    except IndexError:
        sec_total_bjp.append(score_sec[i]["BJP"]+0)

for i in score_sec:
    try:
        sec_total_cong.append(score_sec[i]["Congress"]+sec_total_cong[-1])
    except IndexError:
        sec_total_cong.append(score_sec[i]["Congress"]+0)

for i in score_sec:
    try:
        sec_total_other.append(score_sec[i]["Other"]+sec_total_other[-1])
    except IndexError:
        sec_total_other.append(score_sec[i]["Other"]+0)

# %%
plt.rcParams["figure.figsize"] = [20,15]
plt.figure(num ='Lok Sabha')
plt.plot([i  for i in range(0,4248)],sec_total_bjp,label = 'BJP',color = 'orange')
plt.plot([i  for i in range(0,4248)],sec_total_cong,label = 'Congress',color = 'green')
plt.plot([i  for i in range(0,4248)],sec_total_other,label = 'Other',color = 'black')
plt.style.use('fivethirtyeight')
ax = plt.gca()
plt.grid(True)
plt.legend()
plt.show()
plt.close()

# %% [markdown]
# # Popularity per minute

# %%
score_min = {}
for t in all_min:
    score_min[t] = {"BJP":0,"Congress":0,"Other":0}
for i in range(0,39874):
    t = df["last_updated"][i]
    score_min[(t.date(),t.hour,t.minute)][df["Party"][i]]+=df["Score"][i]

# %%
min_total_bjp, min_total_cong, min_total_other = [],[],[]
for i in score_min:
    try:
        min_total_bjp.append(score_min[i]["BJP"]+min_total_bjp[-1])
    except IndexError:
        min_total_bjp.append(score_min[i]["BJP"]+0)

for i in score_min:
    try:
        min_total_cong.append(score_min[i]["Congress"]+min_total_cong[-1])
    except IndexError:
        min_total_cong.append(score_min[i]["Congress"]+0)

for i in score_min:
    try:
        min_total_other.append(score_min[i]["Other"]+min_total_other[-1])
    except IndexError:
        min_total_other.append(score_min[i]["Other"]+0)

# %%
plt.rcParams["figure.figsize"] = [20,15]
plt.figure(num ='Lok Sabha')
plt.plot([i  for i in range(0,139741)],min_total_bjp,label = 'BJP',color = 'orange')
plt.plot([i  for i in range(0,139741)],min_total_cong,label = 'Congress',color = 'green')
plt.plot([i  for i in range(0,139741)],min_total_other,label = 'Other',color = 'black')
plt.style.use('fivethirtyeight')
ax = plt.gca()
plt.grid(True)
plt.legend()
plt.show()
plt.close()

# %% [markdown]
# # Popularity per hour

# %%
score_hour = {}
for t in all_hour:
    score_hour[t] = {"BJP":0,"Congress":0,"Other":0}
for i in range(0,39874):
    t = df["last_updated"][i]
    score_hour[(t.date(),t.hour)][df["Party"][i]]+=df["Score"][i]

# %%
hour_total_bjp, hour_total_cong, hour_total_other = [],[],[]
for i in score_hour:
    try:
        hour_total_bjp.append(score_hour[i]["BJP"]+hour_total_bjp[-1])
    except IndexError:
        hour_total_bjp.append(score_hour[i]["BJP"]+0)

for i in score_hour:
    try:
        hour_total_cong.append(score_hour[i]["Congress"]+hour_total_cong[-1])
    except IndexError:
        hour_total_cong.append(score_hour[i]["Congress"]+0)

for i in score_hour:
    try:
        hour_total_other.append(score_hour[i]["Other"]+hour_total_other[-1])
    except IndexError:
        hour_total_other.append(score_hour[i]["Other"]+0)

# %%
plt.rcParams["figure.figsize"] = [20,15]
plt.figure(num ='Lok Sabha')
plt.plot([i  for i in range(1,2331)],hour_total_bjp,label = 'BJP',color = 'orange')
plt.plot([i  for i in range(1,2331)],hour_total_cong,label = 'Congress',color = 'green')
plt.plot([i  for i in range(1,2331)],hour_total_other,label = 'Other',color = 'black')
plt.style.use('fivethirtyeight')
ax = plt.gca()
plt.grid(True)
plt.legend()
plt.show()
plt.close()

# %% [markdown]
# # Per Day Popularity over 100 days

# %%
score_day = {}
all_days = []
result=time_day[0]
while result<= time_day[-1]:
    all_days.append(result)
    result+=timedelta(days=1)
#print(all_days)
for t in all_days:
    score_day[t] = {"BJP":0,"Congress":0,"Other":0}
for i in range(0,39874):
    t = df["last_updated"][i]
    score_day[t.date()][df["Party"][i]]+=df["Score"][i]

# %%
day_total_bjp, day_total_cong, day_total_other = [],[],[]
for i in score_day:
    try:
        day_total_bjp.append(score_day[i]["BJP"]+day_total_bjp[-1])
    except IndexError:
        day_total_bjp.append(score_day[i]["BJP"]+0)

for i in score_day:
    try:
        day_total_cong.append(score_day[i]["Congress"]+day_total_cong[-1])
    except IndexError:
        day_total_cong.append(score_day[i]["Congress"]+0)

for i in score_day:
    try:
        day_total_other.append(score_day[i]["Other"]+day_total_other[-1])
    except IndexError:
        day_total_other.append(score_day[i]["Other"]+0)

# %%
plt.rcParams["figure.figsize"] = [20,15]
plt.figure(num ='Lok Sabha')
plt.plot([i  for i in range(0,98)],day_total_bjp,label = 'BJP',color = 'orange')
plt.plot([i  for i in range(0,98)],day_total_cong,label = 'Congress',color = 'green')
plt.plot([i  for i in range(0,98)],day_total_other,label = 'Other',color = 'black')
plt.style.use('ggplot')
ax = plt.gca()
plt.grid(True)
plt.legend()
plt.show()
plt.close()

# %% [markdown]
# # Weekly Popularity over 14 weeks

# %%
score_week = {}
for t in time_week:
    score_week[t] = {"BJP":0,"Congress":0,"Other":0}
last = time_day[0]
ctr = 0
while last<=all_days[-1]:
    if last in time_week:
        score_week[last]["BJP"] = day_total_bjp[ctr]
        score_week[last]["Congress"] = day_total_cong[ctr]
        score_week[last]["Other"] = day_total_other[ctr]
    last+= timedelta(days=1)
    ctr+=1

# %%
week_total_bjp, week_total_cong, week_total_other = [],[],[]
for i in score_week:
    week_total_bjp.append(score_week[i]["BJP"])
    week_total_cong.append(score_week[i]["Congress"])
    week_total_other.append(score_week[i]["Other"])

# %%
plt.rcParams["figure.figsize"] = [20,15]
plt.figure(num ='Lok Sabha')
plt.plot([i  for i in range(1,15)],week_total_bjp,label = 'BJP',color = 'orange')
plt.plot([i  for i in range(1,15)],week_total_cong,label = 'Congress',color = 'green')
plt.plot([i  for i in range(1,15)],week_total_other,label = 'Other',color = 'black')
plt.style.use('fivethirtyeight')
ax = plt.gca()
plt.grid(True)
plt.legend()
plt.show()
plt.close()

# %% [markdown]
# # Fortnightly Popularity over 7 fortnights

# %%
score_fn = {}
for t in time_fortnight:
    score_fn[t] = {"BJP":0,"Congress":0,"Other":0}
last = time_day[0]
ctr = 0
while last<=all_days[-1]:
    if last in time_fortnight:
        score_fn[last]["BJP"] = day_total_bjp[ctr]
        score_fn[last]["Congress"] = day_total_cong[ctr]
        score_fn[last]["Other"] = day_total_other[ctr]
    last+= timedelta(days=1)
    ctr+=1

# %%
fn_total_bjp, fn_total_cong, fn_total_other = [],[],[]
for i in score_fn:
    fn_total_bjp.append(score_fn[i]["BJP"])
    fn_total_cong.append(score_fn[i]["Congress"])
    fn_total_other.append(score_fn[i]["Other"])

# %%
plt.rcParams["figure.figsize"] = [30,15]
plt.figure(num ='Lok Sabha')
plt.plot([i  for i in range(1,8)],fn_total_bjp,label = 'BJP',color = 'orange')
plt.plot([i  for i in range(1,8)],fn_total_cong,label = 'Congress',color = 'green')
plt.plot([i  for i in range(1,8)],fn_total_other,label = 'Other',color = 'black')
plt.style.use('fivethirtyeight')
ax = plt.gca()
plt.grid(True)
plt.legend()
plt.show()
plt.close()

# %% [markdown]
# # Monthly Popularity over 4 months

# %%
score_month = {}
for t in time_month:
    score_month[t] = {"BJP":0,"Congress":0,"Other":0}
for i in range(0,39874):
    t = df["last_updated"][i].month
    score_month[t][df["Party"][i]]+=df["Score"][i]

# %%
month_total_bjp, month_total_cong, month_total_other = [],[],[]
for i in score_month:
    try:
        month_total_bjp.append(score_month[i]["BJP"]+month_total_bjp[-1])
    except IndexError:
        month_total_bjp.append(score_month[i]["BJP"]+0)

for i in score_month:
    try:
        month_total_cong.append(score_month[i]["Congress"]+month_total_cong[-1])
    except IndexError:
        month_total_cong.append(score_month[i]["Congress"]+0)

for i in score_month:
    try:
        month_total_other.append(score_month[i]["Other"]+month_total_other[-1])
    except IndexError:
        month_total_other.append(score_month[i]["Other"]+0)

# %%
plt.rcParams["figure.figsize"] = [30,15]
plt.figure(num ='Lok Sabha')
plt.plot([i  for i in range(1,5)],month_total_bjp,label = 'BJP',color = 'orange')
plt.plot([i  for i in range(1,5)],month_total_cong,label = 'Congress',color = 'green')
plt.plot([i  for i in range(1,5)],month_total_other,label = 'Other',color = 'black')
plt.style.use('fivethirtyeight')
ax = plt.gca()
plt.grid(True)
plt.legend()
plt.show()
plt.close()

# %% [markdown]
# # Day wise Popularity per State

# %%
state_day_score = dict()
for i in set(list(df["State"])):
    if list(df["State"]).count(i)>500 and i!='':
        state_day_score[i]=dict()
        for t in all_days:
            state_day_score[i][t] = {"BJP":0,"Congress":0,"Other":0}

# %%
state_day_score["Other"]=dict()
for t in all_days:
            state_day_score["Other"][t] = {"BJP":0,"Congress":0,"Other":0}

# %%
for i in range(0,39874):
    t = df["last_updated"][i].date()
    st = df["State"][i]
    pty = df["Party"][i]
    cp = df["Score"][i]
    if st in state_day_score:
            state_day_score[st][t][pty]+=cp
    else:
        state_day_score["Other"][t][pty]+=cp

# %%
state_popularity = dict()
for i in state_day_score:
    state_popularity[i] = {"BJP":[],"Congress":[],"Other":[]}

for st in state_day_score:
    for t in state_day_score[st]:
        try:
            state_popularity[st]["BJP"].append(state_day_score[st][t]["BJP"]+state_popularity[st]["BJP"][-1])
        except IndexError:
            state_popularity[st]["BJP"].append(state_day_score[st][t]["BJP"]+0)
            
for st in state_day_score:
    for t in state_day_score[st]:
        try:
            state_popularity[st]["Congress"].append(state_day_score[st][t]["Congress"]+state_popularity[st]["Congress"][-1])
        except IndexError:
            state_popularity[st]["Congress"].append(state_day_score[st][t]["Congress"]+0)

for st in state_day_score:
    for t in state_day_score[st]:
        try:
            state_popularity[st]["Other"].append(state_day_score[st][t]["Other"]+state_popularity[st]["Other"][-1])
        except IndexError:
            state_popularity[st]["Other"].append(state_day_score[st][t]["Other"]+0)

# %%
del state_popularity["Other"]

# %%
plt.rcParams["figure.figsize"] = [20,15]
plt.figure(num ='Lok Sabha')
#colors = ["red","blue","orange","purple","green","violet","pink","black","lightblue","lightgreen","darkred","grey"]
ctr=0
for i in state_popularity:
    plt.plot([i  for i in range(0,98)],state_popularity[i]["BJP"],label = i)
    ctr+=1
plt.style.use('fivethirtyeight')
#plt.figure(figsize=(20,20))
plt.title("Popularity of BJP over Time")
ax = plt.gca()
plt.grid(True)
plt.legend( loc='best', bbox_to_anchor=(1, 0,0.2, 1.02))
plt.show()
plt.close()

# %%
plt.figure(num ='Lok Sabha')
plt.rcParams["figure.figsize"] = [20,15]
for i in state_popularity:
    plt.plot([i  for i in range(0,98)],state_popularity[i]["Congress"],label = i)
plt.style.use('fivethirtyeight')
#plt.figure(figsize=(20,20))
plt.title("Popularity of Congress over Time")
ax = plt.gca()
plt.grid(True)
plt.legend( loc='best', bbox_to_anchor=(1, 0,0.2, 1.02))
plt.show()
plt.close()

# %%
plt.figure(num ='Lok Sabha')
plt.rcParams["figure.figsize"] = [20,15]
for i in state_popularity:
    plt.plot([i  for i in range(0,98)],state_popularity[i]["Other"],label = i)
plt.style.use('fivethirtyeight')
#plt.figure(figsize=(20,20))
ax = plt.gca()
plt.grid(True)
plt.title("Popularity of Other Parties over Time")
plt.legend( loc='best', bbox_to_anchor=(1, 0,0.2, 1.02))
plt.show() 
plt.close()

# %%
df.to_csv("CleanedDataset.csv", index = False)

# %% [markdown]
# # Plotting Final Popularity before Results

# %%
plt.rcParams["figure.figsize"] = [10,10]
x = matplotlib.pyplot.bar(["BJP","Congress","Other"],[day_total_bjp[-1],day_total_cong[-1],day_total_other[-1]],width=0.3,color=["Orange","green","grey"])
plt.legend([x[0],x[1],x[2]],["BJP","Congress","Other"])
plt.title("Final Popularity Index")
# Out:
# Text(0.5, 1.0, 'Final Popularity Index')

# %%
states = list(set(list(df["State"])))
states.remove("")

# %% [markdown]
# # Most tweeted from States

# %%
state_count = dict(df["State"].value_counts())
del state_count[""]
state_count["Other"] = 0
most_state_count = dict()
most_state_count["Other"] =0

# %%
for i in state_count:
    if state_count[i]<150:
        most_state_count["Other"]+=state_count[i]
    else:
        most_state_count[i] = state_count[i]

# %%
plt.rcParams["figure.figsize"] = [30,15]
del most_state_count["Other"]
plt.style.use('fivethirtyeight')
fig = plt.bar(list(most_state_count.keys()),list(most_state_count.values()),width = 0.8)
plt.title("Most Tweeted from States")
# Out:
# Text(0.5, 1.0, 'Most Tweeted from States')

# %%
fp1 = r"INDIA\IND_adm1.shp"
map_df1 = gpd.read_file(fp1)

# %%
count = dict(df["State"].value_counts())
states = list(count.keys())
states.remove("")

# %%
geo=[]
for i in states:
    for j in range(0,36):
        name1 = i
        name2 = map_df1["NAME_1"][j]
        if(name1==name2):
            geo.append(map_df1["geometry"][j])
            break
        elif len(set(name1.split()).intersection(set(name2.split())))>1:
            geo.append(map_df1["geometry"][j])
            break
        elif name2=="Puducherry" and name1 == "Pondicherry":
            geo.append(map_df1["geometry"][j])
            break

# %%
bjp,cong,other,party,tweets,bjppop,congpop,opop=[],[],[],[],[],[],[],[]
partycount = dict()
for i in states:
    partycount[i] = {"BJP":0,"Congress":0,"Other":0,"BJPPop":0,"CongPop":0,"OtherPop":0,
                     'narendramodi':0,'bjp4india':0,'incindia':0,'rahulgandhi':0,
                    "htmodi":0,'htbjp':0,'htloksabha':0,'htcong':0,'htrahulgandhi':0,'htchow':0}

# %%
for i in range(0,39874):
    p = df["Party"][i]
    s = df["State"][i]
    cp = df["Score"][i]
    temp = df["hashtags"][i]
    user = df["user_mentions_screen_name"][i]
    if s=="":
        continue
    partycount[s][p]+=1
    if p=="BJP":
        partycount[s]["BJPPop"]+=cp
    if p=="Congress":
        partycount[s]["CongPop"]+=cp
    if p=="Other":
        partycount[s]["OtherPop"]+=cp
    for hst in temp.split(','):
        if hst =="BJP":
            partycount[s]['htbjp']+=1
        if hst =="Modi":
            partycount[s]['htmodi']+=1
        if hst =="LokSabhaElections2019":
            partycount[s]['htloksabha']+=1
        if hst =="Congress":
            partycount[s]['htcong']+=1
        if hst =="RahulGandhi":
            partycount[s]['htrahulgandhi']+=1
        if hst =="MainBhiChowkidar":
            partycount[s]['htchow']+=1
    for x in user.split(','):
        if x=="BJP4India":
            partycount[s]['bjp4india']+=1
        if x=="narendramodi":
            partycount[s]['narendramodi']+=1
        if x=="INCIndia":
            partycount[s]['incindia']+=1
        if x=="RahulGandhi":
            partycount[s]['rahulgandhi']+=1

# %%
htbjp,htmodi,htls,htcong,htrg,htchow = [],[],[],[],[],[]
hdbjp,hdmodi,hdcong,hdrg=[],[],[],[]

for i in partycount:
    bjp.append(partycount[i]["BJP"])
    cong.append(partycount[i]["Congress"])
    other.append(partycount[i]["Other"])
    tweets.append(partycount[i]["BJP"]+partycount[i]["Congress"]+partycount[i]["Other"])
    bjppop.append(partycount[i]["BJPPop"])
    congpop.append(partycount[i]["CongPop"])
    opop.append(partycount[i]["OtherPop"])
    
    htbjp.append(partycount[i]['htbjp'])
    htmodi.append(partycount[i]['htmodi'])
    htls.append(partycount[i]['htloksabha'])
    htcong.append(partycount[i]['htcong'])
    htrg.append(partycount[i]['htrahulgandhi'])
    htchow.append(partycount[i]['htchow'])
    
    hdbjp.append(partycount[i]['bjp4india'])
    hdmodi.append(partycount[i]['narendramodi'])
    hdcong.append(partycount[i]['incindia'])
    hdrg.append(partycount[i]['rahulgandhi'])
    
    if partycount[i]["BJPPop"]>partycount[i]["CongPop"] and partycount[i]["BJPPop"]>partycount[i]["OtherPop"]:
        party.append("BJP")
    elif partycount[i]["BJPPop"]<partycount[i]["CongPop"] and partycount[i]["OtherPop"]<partycount[i]["CongPop"]:
        party.append("Congress")
    else:
        party.append("Other")

# %%
testdf = pd.DataFrame({"State":states,"Tweets":tweets,"Geo":geo,"Party":party,"BJP":bjp,"Congress":cong,"Other":other,
                      "BJPPop":bjppop,"Congpop":congpop,"OtherPop":opop,
                      "#BJP":htbjp,"#Modi":htmodi,"#LokSabhaElections2019":htls,"#Congress":htcong,"#RahulGandhi":htrg,"#MainBhiChowkidar":htchow,
                      "@BJP4India":hdbjp,"@narendramodi":hdmodi,"@INCIndia":hdcong,"@RahulGandhi":hdrg})
testdf.head()
# Out:
#            State  Tweets                                                Geo  \
# 0          Delhi    4320  POLYGON ((77.32713317871099 28.68515968322754,...
# 1    Maharashtra    2852  (POLYGON ((73.45597076416021 15.88986206054688...
# 2      Karnataka    1587  (POLYGON ((74.67097473144554 13.19986152648931...
# 3  Uttar Pradesh     975  POLYGON ((77.58467864990263 30.4087810516358, ...
# 4     Tamil Nadu     946  (POLYGON ((77.55596160888689 8.079030990600586...
#
#   Party   BJP  Congress  Other        BJPPop       Congpop      OtherPop  \
# 0   BJP  2553      1272    495  98699.558679  55245.874899  11187.691776
# 1   BJP  1714       786    352  34635.647410  11713.134788   5968.931687
# 2   BJP   972       428    187  13217.945864   4299.645774   1714.660174
# 3   BJP   581       275    119   6648.730429   4516.772470   1176.673338
# 4   BJP   650       220     76   4335.489800   3205.668313    370.372162
#
#    #BJP  #Modi  #LokSabhaElections2019  #Congress  #RahulGandhi  \
# 0    38     14                      37         28            19
# 1    31     44                      15         15             4
# 2     7      5                       5          5             7
# 3     7      4                       4          2             1
# 4    18     12                       3          5             2
#
#    #MainBhiChowkidar  @BJP4India  @narendramodi  @INCIndia  @RahulGandhi
# 0                 10          77            312        139           205
# 1                  5          62            226        133           166
# 2                  9          28            141         68            94
# 3                  5          42            125         43            57
# 4                  3          39             87         24            26

# %%
gdf = gpd.GeoDataFrame(testdf, geometry="Geo")

# %%
plt.style.use('default')
plt.rcParams["figure.figsize"] = [15,10]
gdf.plot(column="Tweets",legend = True)
plt.title("Most Tweeted from States")
# Out:
# Text(0.5, 1, 'Most Tweeted from States')

# %%
plt.style.use('default')
plt.rcParams["figure.figsize"] = [15,10]
gdf.plot(column="BJP",legend = True,cmap="Reds")
plt.title("States tweeting about BJP")
# Out:
# Text(0.5, 1, 'States tweeting about BJP')

# %%
plt.style.use('default')
plt.rcParams["figure.figsize"] = [15,10]
gdf.plot(column="Congress",legend = True,cmap="Greens")
plt.title("States tweeting about Congress")
# Out:
# Text(0.5, 1, 'States tweeting about Congress')

# %%
plt.style.use('default')
plt.rcParams["figure.figsize"] = [15,10]
gdf.plot(column="Other",legend = True,cmap = "Blues")
plt.title("States tweeting about Other Parties")
# Out:
# Text(0.5, 1, 'States tweeting about Other Parties')

# %%
plt.style.use('default')
plt.rcParams["figure.figsize"] = [15,10]
gdf.plot(column="Party",legend = True,cmap="inferno")
plt.title("Popularity Trend Across States")
# Out:
# Text(0.5, 1, 'Popularity Trend Across States')

# %%
plt.style.use('default')
plt.rcParams["figure.figsize"] = [15,10]
gdf.plot(column="BJPPop",cmap="Reds",legend = True)
plt.title("BJP Popularity")
# Out:
# Text(0.5, 1, 'BJP Popularity')

# %%
plt.style.use('default')
plt.rcParams["figure.figsize"] = [15,10]
gdf.plot(column="Congpop",cmap="Greens",legend = True)
plt.title("Congress Popularity")
# Out:
# Text(0.5, 1, 'Congress Popularity')

# %%
plt.style.use('default')
plt.rcParams["figure.figsize"] = [15,10]
gdf.plot(column="OtherPop",cmap="Blues",legend = True)
plt.title("Other Party Popularity")
plt.show()

# %% [markdown]
# # Most Tweeted from Cities

# %%
city_count = dict(df["City"].value_counts())
city_count["Other"] = 0
del city_count[""]
most_city_count = dict()
most_city_count["Other"] = 0

# %%
for i in city_count:
    if city_count[i]<200:
        most_city_count["Other"]+=city_count[i]
    else:
        most_city_count[i] = city_count[i]

# %%
del most_city_count["Other"]
plt.rcParams["figure.figsize"] = [30,15]
plt.style.use('fivethirtyeight')
fig = plt.bar(list(most_city_count.keys()),list(most_city_count.values()),width = 0.8)
plt.title("Most Tweeted from Cities")
# Out:
# Text(0.5, 1.0, 'Most Tweeted from Cities')

# %% [markdown]
# # Most Popular Hashtags

# %%
hashtags = []
for i in list(df["hashtags"]):
    x = i.split(',')
    for j in x:
        hashtags.append(j)
hashdata = [i for i in hashtags if i!=""]

# %%
hash_count = dict()
hash_count["Other"] = 0
for i in set(hashtags):
    x = hashtags.count(i)
    if x<60: #70 is best count
        hash_count["Other"]+= x
    else:
        hash_count[i] = x
del hash_count[""]
del hash_count["Other"]

# %%
plt.style.use("fivethirtyeight")
plt.rcParams["figure.figsize"] = [30,15]
fig = plt.bar(list(hash_count.keys()),list(hash_count.values()),width = 0.5)
plt.title("Most Popular Hashtags")
# Out:
# Text(0.5, 1.0, 'Most Popular Hashtags')

# %%
plt.style.use('default')
plt.rcParams["figure.figsize"] = [10,5]
gdf.plot(column="#BJP",legend = True,cmap="Reds")
plt.title("#BJP")
# Out:
# Text(0.5, 1, '#BJP')

# %%
plt.style.use('default')
plt.rcParams["figure.figsize"] = [10,5]
gdf.plot(column="#Modi",legend = True,cmap="Reds")
plt.title("#Modi")
# Out:
# Text(0.5, 1, '#Modi')

# %%
plt.style.use('default')
plt.rcParams["figure.figsize"] = [10,5]
gdf.plot(column="#Congress",legend = True,cmap="Greens")
plt.title("#Congress")
# Out:
# Text(0.5, 1, '#Congress')

# %%
plt.style.use('default')
plt.rcParams["figure.figsize"] = [10,5]
gdf.plot(column="#RahulGandhi",legend = True,cmap="Greens")
plt.title("#RahulGandhi")
# Out:
# Text(0.5, 1, '#RahulGandhi')

# %%
plt.style.use('default')
plt.rcParams["figure.figsize"] = [10,5]
gdf.plot(column="#MainBhiChowkidar",legend = True,cmap="Reds")
plt.title("#MainBhiChowkidar")
# Out:
# Text(0.5, 1, '#MainBhiChowkidar')

# %%
plt.style.use('default')
plt.rcParams["figure.figsize"] = [10,5]
gdf.plot(column="#LokSabhaElections2019",legend = True)
plt.title("#LokSabhaElections2019")
# Out:
# Text(0.5, 1, '#LokSabhaElections2019')

# %% [markdown]
# # Most Tagged Handles

# %%
handles = []
for i in df["user_mentions_screen_name"]:
    x = i.split(',')
    for j in x:
        handles.append(j)
handles = [i for i in handles if i!=""]

# %%
handle_count = dict()
handle_count["Other"] = 0
for i in set(handles):
    x = handles.count(i)
    if x<120:
        handle_count["Other"]+= x
    else:
        handle_count[i] = x
#del handle_count[""]
del handle_count["Other"]

# %%
plt.rcParams["figure.figsize"] = [20,10]
fig = plt.bar(list(handle_count.keys()),list(handle_count.values()),width = 0.8)
plt.title("Most Tagged Handles")
# Out:
# Text(0.5, 1.0, 'Most Tagged Handles')

# %%
plt.style.use('default')
plt.rcParams["figure.figsize"] = [10,5]
gdf.plot(column="@narendramodi",legend = True,cmap="Reds")
plt.title("People tagging @Modi")
# Out:
# Text(0.5, 1, 'People tagging @Modi')

# %%
plt.style.use('default')
plt.rcParams["figure.figsize"] = [10,5]
gdf.plot(column="@BJP4India",legend = True,cmap="Reds")
plt.title("People tagging @BJP4India")
# Out:
# Text(0.5, 1, 'People tagging @BJP4India')

# %%
plt.style.use('default')
plt.rcParams["figure.figsize"] = [10,5]
gdf.plot(column="@INCIndia",legend = True,cmap="Greens")
plt.title("People tagging @Congress")
# Out:
# Text(0.5, 1, 'People tagging @Congress')

# %%
plt.style.use('default')
plt.rcParams["figure.figsize"] = [10,5]
gdf.plot(column="@RahulGandhi",legend = True,cmap="Greens")
plt.title("People tagging @RahulGandhi")
# Out:
# Text(0.5, 1, 'People tagging @RahulGandhi')

# %% [markdown]
# # Frequency of Tweets per Day

# %%
tweets_per_day = dict()
for i in all_days:
    tweets_per_day[i]=0
for i in range(0,39874):
    tweets_per_day[df["last_updated"][i].date()]+=1

# %%
temp = dict()
for i in tweets_per_day:
    if tweets_per_day[i]!=0:
        temp[i] = tweets_per_day[i]
        #tweets_per_day[i] = tweets_per_day[i-timedelta(days=1)]     
tweets_per_day = temp

# %%
plt.rcParams["figure.figsize"] = [15,10]
plt.plot([i  for i in range(len(tweets_per_day.keys()))],list(tweets_per_day.values()))
plt.style.use('fivethirtyeight')
#plt.figure(figsize=(20,20))
ax = plt.gca()
plt.grid(True)
plt.title("Frequency of Tweets per Day")
#plt.legend( loc='best', bbox_to_anchor=(1, 0,0.2, 1.02))
plt.show()
plt.close()

# %% [markdown]
# # Tagging Frequency over Time

# %%
ht = ["narendramodi","BJP4India","RahulGandhi","INCIndia"]
ht_time = dict()
for i in all_days:
    ht_time[i] = {"narendramodi":0,"BJP4India":0,"RahulGandhi":0,"INCIndia":0}

# %%
for i in range(0,39874):
    t = df["last_updated"][i].date()
    temp = df["user_mentions_screen_name"][i].split(',')
    for j in temp:
        if j in ht:
            ht_time[t][j]+=1

# %%
modi_tag1 = []
bjp_tag1 = []
rahulgandhi_tag1 = []
cong_tag1 = []
modi_tag2 = []
bjp_tag2 = []
rahulgandhi_tag2 = []
cong_tag2 = []

for t in ht_time:
    temp = ht_time[t]
    try:
        modi_tag1.append(temp["narendramodi"])
        modi_tag2.append(modi_tag2[-1]+temp["narendramodi"])
    except:
        modi_tag2.append(0+temp["narendramodi"])
        
for t in ht_time:
    temp = ht_time[t]
    try:
        bjp_tag1.append(temp["BJP4India"])
        bjp_tag2.append(bjp_tag2[-1]+temp["BJP4India"])
    except:
        bjp_tag2.append(0+temp["BJP4India"])
        
for t in ht_time:
    temp = ht_time[t]
    try:
        rahulgandhi_tag1.append(temp["RahulGandhi"])
        rahulgandhi_tag2.append(rahulgandhi_tag2[-1]+temp["RahulGandhi"])
    except:
        rahulgandhi_tag2.append(0+temp["RahulGandhi"])
        
for t in ht_time:
    temp = ht_time[t]
    try:
        cong_tag1.append(temp["INCIndia"])
        cong_tag2.append(cong_tag2[-1]+temp["INCIndia"])
    except:
        cong_tag2.append(0+temp["INCIndia"])
        
        
tagged_scores = {"narendramodi":[modi_tag1,modi_tag2],"BJP4India":[bjp_tag1,bjp_tag2],
                "RahulGandhi":[rahulgandhi_tag1,rahulgandhi_tag2],"INCIndia":[cong_tag1,cong_tag2]}

# %%
plt.figure(num ='Lok Sabha')
plt.rcParams["figure.figsize"] = [8,2]
for i in ht:
    plt.plot([i  for i in range(0,98)],tagged_scores[i][0],label = i)
plt.style.use('fivethirtyeight')
plt.title("Frequency of Tagging")
plt.grid(True)
ax = plt.gca()
plt.legend(loc='best', bbox_to_anchor=(1, 0,0.2, 1.02))
plt.show()
plt.close()

# %%
plt.figure(num ='Lok Sabha')
plt.rcParams["figure.figsize"] = [15,5]
for i in ht:
    plt.plot([i  for i in range(0,98)],tagged_scores[i][1],label = i)
plt.style.use('fivethirtyeight')
plt.title("Popularity of Handles over Time")
plt.grid(True)
ax = plt.gca()
plt.legend(loc='best', bbox_to_anchor=(1, 0,0.2, 1.02))
plt.show()
plt.close()

# %% [markdown]
# # Discrete Probabilites

# %%
vote_score = dict()
for i in all_days:
  vote_score[i] = {"bjp_votes":0, "cong_votes":0, "other_votes":0, "cong_coal":0, "bjp_coal":0,"total":0}
#bjp_votes, cong_votes, other_votes, cong_coal, bjp_coal = [0 for i in range(5)]
total = 0
for i in range(0,39874):
  t = df["last_updated"][i].date()
  party = df["Party"][i]
  score = df["Score"][i]
  scoreadd=1
  if party=="BJP":
    if score>0:
      vote_score[t]["bjp_votes"]+=scoreadd
      vote_score[t]["total"]+=1
    else:
      if score >=-0.4 and score <=0:
        vote_score[t]["cong_coal"]+=scoreadd
        vote_score[t]["total"]+=1
      else:
        vote_score[t]["cong_votes"]+=scoreadd
        vote_score[t]["total"]+=1
  elif party=="Congress":
    if score>0:
      vote_score[t]["cong_votes"]+=scoreadd
      vote_score[t]["total"]+=1
    else:
      if score >=-0.4 and score <=0:
        vote_score[t]["bjp_coal"]+=scoreadd
        vote_score[t]["total"]+=1
      else:
        vote_score[t]["bjp_votes"]+=scoreadd
        vote_score[t]["total"]+=1
  else:
    if score>0:
      vote_score[t]["other_votes"]+=scoreadd
      vote_score[t]["total"]+=1
    elif score >=-0.4 and score <=0:
      if vote_score[t]["bjp_votes"]>vote_score[t]["cong_votes"]:
        vote_score[t]["bjp_coal"]+=scoreadd
        vote_score[t]["total"]+=1
      else:
        vote_score[t]["cong_coal"]+=scoreadd
        vote_score[t]["total"]+=1

# %%
vote_bjp1, vote_cong1, vote_other1, vote_bjp_coal1, vote_cong_coal1 = [],[],[],[],[]
vote_bjp2, vote_cong2, vote_other2, vote_bjp_coal2, vote_cong_coal2 = [],[],[],[],[]
temp = dict()
for i in vote_score:
    if vote_score[i]["total"]!=0:
        temp[i] = vote_score[i]
vote_score=temp
for t in vote_score:
  if vote_score[t]['total']==0:
    continue
  vote_bjp1.append((vote_score[t]["bjp_votes"]/vote_score[t]["total"]))
  try:
    vote_bjp2.append((vote_score[t]["bjp_votes"]+vote_bjp2[-1])/(vote_score[t]["total"]+vote_score[t-timedelta(days=1)]["total"]))
  except:
    vote_bjp2.append((vote_score[t]["bjp_votes"]/vote_score[t]["total"]))

for t in vote_score:
  if vote_score[t]['total']==0:
    continue
  vote_cong1.append((vote_score[t]["cong_votes"]/vote_score[t]["total"]))
  try:
    vote_cong2.append((vote_score[t]["cong_votes"]+vote_cong2[-1])/(vote_score[t]["total"]+vote_score[t-timedelta(days=1)]["total"]))
  except:
    vote_cong2.append((vote_score[t]["cong_votes"]/vote_score[t]["total"]))

for t in vote_score:
  if vote_score[t]['total']==0:
    continue
  vote_other1.append((vote_score[t]["other_votes"]/vote_score[t]["total"]))
  try:
    vote_other2.append((vote_score[t]["other_votes"]+vote_other2[-1])/(vote_score[t]["total"]+vote_score[t-timedelta(days=1)]["total"]))
  except:
    vote_other2.append((vote_score[t]["other_votes"]/vote_score[t]["total"]))

for t in vote_score:
  if vote_score[t]['total']==0:
    continue
  vote_bjp_coal1.append((vote_score[t]["bjp_coal"]/vote_score[t]["total"]))
  try:
    vote_bjp_coal2.append((vote_score[t]["bjp_coal"]+vote_bjp_coal2[-1])/(vote_score[t]["total"]+vote_score[t-timedelta(days=1)]["total"]))
  except:
    vote_bjp_coal2.append((vote_score[t]["bjp_coal"]/vote_score[t]["total"]))

for t in vote_score:
  if vote_score[t]['total']==0:
    continue
  vote_cong_coal1.append((vote_score[t]["cong_coal"]/vote_score[t]["total"]))
  try:
    vote_cong_coal2.append((vote_score[t]["cong_coal"]+vote_cong_coal2[-1])/(vote_score[t]["total"]+vote_score[t-timedelta(days=1)]["total"]))
  except:
    vote_cong_coal2.append((vote_score[t]["cong_coal"]/vote_score[t]["total"]))

# %%
plt.figure(num ='Lok Sabha')
plt.rcParams["figure.figsize"] = [15,5]
labels = ["BJP","Congress","Other","BJP Coalition","Congress Coalition"]
x = [vote_bjp1, vote_cong1, vote_other1, vote_bjp_coal1, vote_cong_coal1]
for i in x:
    plt.plot([j  for j in range(len(i))],i,label= labels[x.index(i)])
plt.style.use('fivethirtyeight')
plt.title("Winning Probability")
plt.grid(True)
ax = plt.gca()
plt.legend(loc='best', bbox_to_anchor=(1, 0,0.2, 1.02))
plt.show()
plt.close()

# %%
plt.figure(num ='Lok Sabha')
plt.rcParams["figure.figsize"] = [15,5]
labels = ["BJP","Congress","Other","BJP Coalition","Congress Coalition"]
x = [vote_bjp2,vote_cong2, vote_other2, vote_bjp_coal2, vote_cong_coal2]
for i in x:
    plt.plot([j  for j in range(len(i))],i,label = labels[x.index(i)])
plt.style.use('fivethirtyeight')
plt.title("Chances of Winning")
plt.grid(True)
ax = plt.gca()
plt.legend(loc='best', bbox_to_anchor=(1, 0,0.2, 1.02))
plt.show()
plt.close()

# %% [markdown]
# # Poisson

# %%
poisson = dict()
for i in all_days:
    poisson[i] = {"bjp":0,"cong":0,"other":0,"bjp_coal":0,"cong_coal":0}
for t in vote_score:
    poisson[t]["bjp"]=vote_score[t]["bjp_votes"]
    poisson[t]["cong"]=vote_score[t]["cong_votes"]
    poisson[t]["other"]=vote_score[t]["other_votes"]
    poisson[t]["bjp_coal"]=vote_score[t]["bjp_coal"]
    poisson[t]["cong_coal"]=vote_score[t]["cong_coal"]

# %%
finalposisson = {"bjp":0,"cong":0,"other":0,"bjp_coal":0,"cong_coal":0}
for t in poisson:
    finalposisson["bjp"]+=poisson[t]["bjp"]
    finalposisson["cong"]+=poisson[t]["cong"]
    finalposisson["other"]+=poisson[t]["other"]
    finalposisson["bjp_coal"]+=poisson[t]["bjp_coal"]
    finalposisson["cong_coal"]+=poisson[t]["cong_coal"]

# %%
l = len(list(poisson.keys()))
for i in finalposisson:
    finalposisson["bjp"]/=98
    finalposisson["cong"]/=98
    finalposisson["other"]/=98
    finalposisson["bjp_coal"]/=98
    finalposisson["cong_coal"]/=98

# %%
finalposisson
# Out:
# {'bjp': 2.048630816500316e-06,
#  'cong': 1.435524002317102e-06,
#  'other': 4.1906326454817995e-07,
#  'bjp_coal': 2.3718892270097617e-07,
#  'cong_coal': 2.708201878600698e-07}

# %%
from math import e,factorial

# %%
poissondist = []
y1,y2,y3,y4,y5 = [],[],[],[],[]
lam1 = finalposisson["bjp"]
lam2 = finalposisson["cong"]
lam3 = finalposisson["other"]
lam4 = finalposisson["bjp_coal"]
lam5 = finalposisson["cong_coal"]
for i in range(0,98):
    y1.append((((e**(-lam1))*(lam1**i))/factorial(i)))
    y2.append((((e**(-lam2))*(lam2**i))/factorial(i)))
    y3.append((((e**(-lam3))*(lam3**i))/factorial(i)))
    y4.append((((e**(-lam4))*(lam4**i))/factorial(i)))
    y5.append((((e**(-lam5))*(lam5**i))/factorial(i)))

# %%
plt.rcParams["figure.figsize"] = [10,10]
plt.hist(y1,[i for i in range(0,98)],color = 'red')
plt.hist(y2,[i for i in range(0,98)],color= 'blue')
plt.hist(y3,[i for i in range(0,98)])
plt.hist(y4,[i for i in range(0,98)])
plt.hist(y5,[i for i in range(0,98)])
ax = plt.gca()
plt.legend(loc='best', bbox_to_anchor=(1, 0,0.2, 1.02))
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
end_time = time.time()
print("Total Execution Time: ",int((end_time-start_time)/60),"min", (int(end_time)-int(start_time))%60,"s")
# Out:
# Total Execution Time:  98 min 40 s

# %% [markdown]
# # Gaussian Probability

# %%
bjpgp = {"Tweets":0, "Score":0, "ScoreArray":[]}
conggp = {"Tweets":0, "Score":0, "ScoreArray":[]}
othergp = {"Tweets":0, "Score":0, "ScoreArray":[]}

for i in range(0,39874):
    if df["Party"][i] == "BJP":
        bjpgp["Tweets"]+=1
        bjpgp["Score"]+=df["Compound"][i]
        bjpgp["ScoreArray"].append(df["Compound"][i])
    elif df["Party"][i] == "Congress":
        conggp["Tweets"]+=1
        conggp["Score"]+=df["Compound"][i]
        conggp["ScoreArray"].append(df["Score"][i])
    else:
        othergp["Tweets"]+=1
        othergp["Score"]+=df["Compound"][i]
        othergp["ScoreArray"].append(df["Compound"][i])

meanbjpgp, meanconggp, meanothergp = bjpgp["Score"]/bjpgp["Tweets"],conggp["Score"]/conggp["Tweets"],othergp["Score"]/othergp["Tweets"]

# %%
bjpsd, congsd, othersd = np.std(bjpgp["ScoreArray"]),np.std(conggp["ScoreArray"]),np.std(othergp["ScoreArray"])

# %%
from math import *

# %%
f = lambda x,y,ctr: (1/(sqrt(2*pi)*y))*e**-((ctr-x)**2/2*(y**2))

# %%
y = []
for i in range(0,39874):
    y.append(f(meanbjpgp,bjpsd,i))

# %%
plt.plot([i for i in range(len(y))],y)
